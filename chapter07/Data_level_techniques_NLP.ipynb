# %% [markdown]
# <a href="https://colab.research.google.com/github/packtpublishing/Machine-Learning-for-Imbalanced-Data/blob/main/chapter07/Data_level_techniques_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# References: https://amitness.com/2020/05/data-augmentation-for-nlp/
#
# Dataset taken from: https://www.kaggle.com/datasets/team-ai/spam-text-message-classification?datasetId=2050&searchQuery=sampling
#
# Dataset License: CC0: Public Domain
#
# Some of the code is adapted from https://www.kaggle.com/code/jth359/imbalanced-target-variable-with-text-data

# %%
import pandas as pd
import numpy as np

url = "https://drive.google.com/file/d/1HQ4mqidhJKLhNEOd6agMDv_nl2caSlNB/view?usp=share_link"
url = "https://drive.google.com/uc?id=" + url.split("/")[-2]
df = pd.read_csv(url)

df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df["Category"].value_counts()
# Out:
# ham     4825
# spam     747
# Name: Category, dtype: int64

# %% [markdown]
# 87% of our data is of class ham and 13% is of class spam
#
# For this notebook, I am going to be focusing on different techniques for handling imbalanced classes.  For this reason I am going to be using TF-IDF and a Logistic Regression Classifier for all of the different techniques.

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# convert all text to lowercase
df["Message"] = df["Message"].str.lower()

# perform train test split
X_train, X_test, y_train, y_test = train_test_split(
    df["Message"], df["Category"], stratify=df["Category"], random_state=11
)

# vectorize text using TFIDF
tfidf = TfidfVectorizer()
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
from collections import Counter

print(len(X_train))
print(Counter(y_train))
# Out:
# 4179
# Counter({'ham': 3619, 'spam': 560})

# %% [markdown]
# To begin we are starting with a logistic regression model where we do not do anything to the classes even though they are imbalanced
#
#
#
#
#
# ### Baseline Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

lr = LogisticRegression(random_state=42)
lr.fit(X_train_tfidf, y_train)
print(classification_report(y_test, lr.predict(X_test_tfidf)))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98      1206
#         spam       0.99      0.78      0.87       187
#
#     accuracy                           0.97      1393
#    macro avg       0.98      0.89      0.93      1393
# weighted avg       0.97      0.97      0.97      1393

# %% [markdown]
# I see that I get a relatively low recall on the minority class `spam` of 0.85
#
# ### Random Over Sampling
#
# Next I am going to try random over sampling

# %%
df["Category"].value_counts()
# Out:
# ham     4825
# spam     747
# Name: Category, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler()
X_ros, y_ros = ros.fit_resample(X_train_tfidf, y_train)

# check distribution after applying over sampling
y_ros.value_counts()
# Out:
# ham     3619
# spam    3619
# Name: Category, dtype: int64

# %% [markdown]
# Applying the same model with the over sampled data

# %%
lr = LogisticRegression(random_state=42)
lr.fit(X_ros, y_ros)
print(classification_report(y_test, lr.predict(X_test_tfidf)))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99      1206
#         spam       0.93      0.95      0.94       187
#
#     accuracy                           0.98      1393
#    macro avg       0.96      0.97      0.96      1393
# weighted avg       0.98      0.98      0.98      1393

# %% [markdown]
# F1-Score for the minority class went down to 0.88

# %% [markdown]
# I see that I get a relatively low recall on the minority class `spam` of 0.85
#
# ### Random Underampling
#
# Next I am going to try random undersampling

# %%
df["Category"].value_counts()
# Out:
# ham     4825
# spam     747
# Name: Category, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

ros = RandomUnderSampler()
X_ros, y_ros = ros.fit_resample(X_train_tfidf, y_train)

# check distribution after applying over sampling
y_ros.value_counts()
# Out:
# ham     560
# spam    560
# Name: Category, dtype: int64

# %% [markdown]
# Applying the same model with the over sampled data

# %%
lr = LogisticRegression(random_state=42)
lr.fit(X_ros, y_ros)
print(classification_report(y_test, lr.predict(X_test_tfidf)))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.99      0.98      0.98      1206
#         spam       0.85      0.94      0.90       187
#
#     accuracy                           0.97      1393
#    macro avg       0.92      0.96      0.94      1393
# weighted avg       0.97      0.97      0.97      1393

# %% [markdown]
# F1-Score for the minority class is 0.89

# %% [markdown]
# ### Data Augmentation
#
# Now we will try translating the Spam Messages to another language and then translate them back to English.  The idea is that we will add a little noise by performing a translation.
#
# An example of this can be seen below

# %% [markdown]
# Now lets see an example of this for a single message.  I am going to take a message, translate it to French, and then translate it back to English

# %% [markdown]
# # Text augmentation using Back Translation using nlpaug library

# %%
# !pip install numpy requests nlpaug transformers sacremoses
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Collecting nlpaug
#   Downloading nlpaug-1.1.11-py3-none-any.whl (410 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 4.5 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 21.5 MB/s eta 0:00:00
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 35.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (1.5.3)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 54.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.3.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (4.11.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2022.7.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests) (1.7.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895239 sha256=523b2c06554c5fcc5cec9511beeb8c4a74e1b4061435b9e6913e776c62935e2c
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
# Successfully built sacremoses
# Installing collected packages: tokenizers, safetensors, sacremoses, huggingface-hub, transformers, nlpaug
# Successfully installed huggingface-hub-0.16.4 nlpaug-1.1.11 sacremoses-0.0.53 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.31.0

# %%
import nlpaug.augmenter.word as naw

text = "The quick brown fox jumped over the lazy dog"
back_translation_aug = naw.BackTranslationAug(
    from_model_name="facebook/wmt19-en-de", to_model_name="facebook/wmt19-de-en"
)
back_translation_aug.augment(text)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# Some weights of FSMTForConditionalGeneration were not initialized from the model checkpoint at facebook/wmt19-en-de and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)neration_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# Some weights of FSMTForConditionalGeneration were not initialized from the model checkpoint at facebook/wmt19-de-en and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)neration_config.json:   0%|          | 0.00/260 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading (…)/main/vocab-src.json:   0%|          | 0.00/849k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading (…)/main/vocab-src.json:   0%|          | 0.00/849k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]
# ['The speedy brown fox leapt over the lazy dog']

# %%
df
# Out:
#      Category                                            Message
# 0         ham  go until jurong point, crazy.. available only ...
# 1         ham                      ok lar... joking wif u oni...
# 2        spam  free entry in 2 a wkly comp to win fa cup fina...
# 3         ham  u dun say so early hor... u c already then say...
# 4         ham  nah i don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  this is the 2nd time we have tried 2 contact u...
# 5568      ham               will ü b going to esplanade fr home?
# 5569      ham  pity, * was in mood for that. so...any other s...
# 5570      ham  the guy did some bitching but i acted like i'd...
# 5571      ham                         rofl. its true to its name
#
# [5572 rows x 2 columns]

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_train.head(2)
# Out:
#                                                 Message Category
# 1426          i'll be at mu in like  &lt;#&gt;  seconds      ham
# 1247  i do know what u mean,  is the king of not hav...      ham

# %%
import time
import nlpaug.augmenter.word as naw

back_translation_aug = naw.BackTranslationAug(
    from_model_name="facebook/wmt19-en-de", to_model_name="facebook/wmt19-de-en"
)
translated_texts = []

for message in df_train[df_train["Category"] == "spam"]["Message"]:
    new_msg = back_translation_aug.augment(message)[0]
    print(message, "  |   ", new_msg)
    translated_texts.append(new_msg)
# Out:
# for sale - arsenal dartboard. good condition but no doubles or trebles!   |    for sale - Arsenal dartboard. Good condition, but no doubles or triplets!
# 500 new mobiles from 2004, must go! txt: nokia to no: 89545 & collect yours today!from only £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18 txtauction   |    500 new phones from 2004, must go! txt: nokia to no: 89545 & collect yours today! from just £1 www.4-tc.biz 2optout 087187262701.50gbp / mtmsg18 txtauction
# urgent! we are trying to contact u. todays draw shows that you have won a £2000 prize guaranteed. call 09058094507 from land line. claim 3030. valid 12hrs only   |    s draw shows you have won a guaranteed prize of £2000. call 09058094507 from country. claim 3030. valid only 12 hours
# text banneduk to 89555 to see! cost 150p textoperator g696ga 18+ xxx   |    Text banneduk to 89555 to see! cost 150p textoperator g696ga 18 + xxx
# as a sim subscriber, you are selected to receive a bonus! get it delivered to your door, txt the word ok to no: 88600 to claim. 150p/msg, exp. 30apr   |    As a SIM subscriber you will be selected to receive a bonus! get it delivered home, txt the word ok to claim no.: 88600. 150p / msg, exp. 30apr
# todays vodafone numbers ending with 0089(my last four digits) are selected to received a £350 award. if your number matches please call 09063442151 to claim your £350 award   |    Today's Vodafone numbers ending in 0089 (my last four digits) will be selected to receive a £350 surcharge. If your number matches, please call 09063442151 to claim your £350 surcharge.
# urgent! please call 09061743810 from landline. your abta complimentary 4* tenerife holiday or #5000 cash await collection sae t&cs box 326 cw25wx 150 ppm   |    urgent! please call 09061743810 from landline. your abta free 4 * tenerife holiday or # 5000 cash waiting for collection sae t & cs box 326 cw25wx 150 ppm
# dear voucher holder, to claim this weeks offer, at you pc please go to http://www.e-tlp.co.uk/reward. ts&cs apply.   |    Dear Voucher Holder, To take advantage of this week's offer, please visit http: / / www.e-tlp.de / reward. ts & cs apply.
# got what it takes 2 take part in the wrc rally in oz? u can with lucozade energy! text rally le to 61200 (25p), see packs or lucozade.co.uk/wrc & itcould be u!   |    has what it takes to take part in the wrc rally in oz? u can use lucozade energy! Text rally le to 61200 (25p), see packages or lucozade.co.uk / wrc & itcould be u!
# this msg is for your mobile content order it has been resent as previous attempt failed due to network error queries to customersqueries@netvision.uk.com   |    This msg is for your mobile content ordering and has been returned as a previous attempt failed due to network error queries to customersqueries @ netvision.uk.com.
# well done! your 4* costa del sol holiday or £5000 await collection. call 09050090044 now toclaim. sae, tcs, pobox334, stockport, sk38xh, cost£1.50/pm, max10mins   |    well done! your 4 star holiday on the Costa del Sol or £5000 waiting to be picked up. Call 09050090044 now. Sae, tcs, pobox334, stockport, sk38xh, cost £1.50 / pm, max10min
# call 09095350301 and send our girls into erotic ecstacy. just 60p/min. to stop texts call 08712460324 (nat rate)   |    Call 09095350301 and send our girls into erotic ecstasy. Only 60p / min. to stop texting call 08712460324 (nat rate)
# text pass to 69669 to collect your polyphonic ringtones. normal gprs charges apply only. enjoy your tones   |    Text Pass to 69669 to collect your polyphonic ringtones. Normal gprs fees apply only. Enjoy your tones
# free for 1st week! no1 nokia tone 4 ur mobile every week just txt nokia to 8077 get txting and tell ur mates. www.getzed.co.uk pobox 36504 w45wq 16+ norm150p/tone   |    free for the 1st week! no1 nokia tone 4 ur mobile every week just txt nokia to 8077 get txting and tell ur mates. www.getzed.co.uk pobox 36504 w45wq 16 + norm150p / tone
# ur balance is now £500. ur next question is: who sang 'uptown girl' in the 80's ? 2 answer txt ur answer to 83600. good luck!   |    Our next question is: Who sang "Uptown Girl" in the 80s? 2 Answer txt ur Answer to 83600. Good luck!
# hi its lucy hubby at meetins all day fri & i will b alone at hotel u fancy cumin over? pls leave msg 2day 09099726395 lucy x calls£1/minmobsmorelkpobox177hp51fl   |    hello be lucy husband at meeting all day fri & i will b alone in hotel u fancy cumin over? pls leave msg 2day 09099726395 lucy x calls £1 / minmobsmorelkpobox177hp51fl
# urgent! you have won a 1 week free membership in our £100,000 prize jackpot! txt the word: claim to no: 81010 t&c www.dbuk.net lccltd pobox 4403ldnw1a7rw18   |    urgently! You have won a 1-week free membership in our £100,000 prize jackpot! txt the word: Claim to no: 81010 t & c www.dbuk.net lccltd pobox 4403ldnw1a7rw18
# 88800 and 89034 are premium phone services call 08718711108   |    88800 and 89034 are premium telephony services on 08718711108
# ringtone club: get the uk singles chart on your mobile each week and choose any top quality ringtone! this message is free of charge.   |    Ringtone Club: Get the UK Singles Charts on your mobile phone every week and choose any top quality ringtone! This message is free of charge.
# spook up your mob with a halloween collection of a logo & pic message plus a free eerie tone, txt card spook to 8007 zed 08701417012150p per logo/pic   |    Spit your mob with a Halloween collection of logo & picture message plus free spooky sound, text card spooks at 8007 08701417012150p per logo / picture
# ringtoneking 84484   |    Ring tone 84484
# free 1st week entry 2 textpod 4 a chance 2 win 40gb ipod or £250 cash every wk. txt pod to 84128 ts&cs www.textpod.net custcare 08712405020.   |    Free 1st week entry 2 textpod 4 a chance 2 win 40gb ipod or £250 cash each wk. txt pod to 84128 ts & cs www.textpod.net custcare 08712405020.
# (bank of granite issues strong-buy) explosive pick for our members *****up over 300% *********** nasdaq symbol cdgt that is a $5.00 per..   |    (Bank of Granite Issues strong-buy) explosive pick-up for our members * * * * * * * by over 300% * * * * * * nasdaq symbol cdgt, which is $5.00 each.
# winner! as a valued network customer you hvae been selected to receive a £900 reward! to collect call 09061701444. valid 24 hours only. acl03530150pm   |    Winner! as a valued network customer you were selected to receive a £900 reward! to receive the call 09061701444, which is valid for only 24 hours. acl03530150pm
# you are chosen to receive a £350 award! pls call claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer.   |    You will be selected to receive a £350 reward! pls call 09066364311 to pick up your reward which you will receive as a valued mobile customer.
# you are being contacted by our dating service by someone you know! to find out who it is, call from your mobile or landline 09064017305 pobox75ldns7   |    You will be contacted by someone you know through our dating service! To find out who it is please call 09064017305 pobox75ldns7 from your mobile or landline.
# latest news! police station toilet stolen, cops have nothing to go on!   |    The latest news! Police station toilet stolen, cops have nothing to do!
# urgent! please call 0906346330. your abta complimentary 4* spanish holiday or £10,000 cash await collection sae t&cs box 47 po19 2ez 150ppm 18+   |    Urgent! Call 0906346330 to expect your ABTA free 4 * Spanish holidays or £10,000 cash collection sae t & cs box 47 po19 2ez 150ppm 18 +
# six chances to win cash! from 100 to 20,000 pounds txt> csh11 and send to 87575. cost 150p/day, 6days, 16+ tsandcs apply reply hl 4 info   |    six chances to win cash! from 100 to 20,000 pounds txt > csh11 and send to 87575. Costs 150p / day, 6 days, 16 + tsandcs apply reply hl 4 info
# urgent! your mobile number has been awarded with a £2000 prize guaranteed. call 09058094454 from land line. claim 3030. valid 12hrs only   |    Your mobile number was rewarded with a guaranteed prize of £2,000, so call 09058094454 from a landline.
# bored of speed dating? try speedchat, txt speedchat to 80155, if you don't like em txt swap and get a new chatter! chat80155 pobox36504w45wq 150p/msg rcd 16   |    Bored with speed dating? Try Speedchat, txt speed chat on 80155 if you don't like the txt swap and you get a new chat! chat80155 pobox36504w45wq 150p / msg rcd 16
# do you want a new nokia 3510i colour phone deliveredtomorrow? with 300 free minutes to any mobile + 100 free texts + free camcorder reply or call 08000930705.   |    want a new nokia 3510i color phone that will be delivered tomorrow? with 300 free minutes on each phone + 100 free texts + free camcorder answer or call 08000930705.
# not heard from u4 a while. call me now am here all night with just my knickers on. make me beg for it like u did last time 01223585236 xx luv nikiyu4.net   |    not heard from u4 a while. call me now I am here all night just wearing my underpants on. ask me how u did it last time 01223585236 xx luv nikiyu4.net
# sports fans - get the latest sports news str* 2 ur mobile 1 wk free plus a free tone txt sport on to 8007 www.getzed.co.uk 0870141701216+ norm 4txt/120p   |    Sports fans - get the latest sports news on mobile 1 wk free plus a free tone txt sport on to 8007 www.getzed.co.uk 0870141701216 + 4txt / 120p
# dorothy@kiefer.com (bank of granite issues strong-buy) explosive pick for our members *****up over 300% *********** nasdaq symbol cdgt that is a $5.00 per..   |    dorothy @ kiefer.com (Bank of Granit issues strong buy) explosive pick-up for our members * * * * * * by over 300% * * * * * * nasdaq symbol cdgt, that is $5.00 per..
# free game. get rayman golf 4 free from the o2 games arcade. 1st get ur games settings. reply post, then save & activ8. press 0 key for arcade. termsapply   |    Free game. get Rayman Golf 4 for free from the o2 arcade. 1. get our game settings. Reply, then save & activate. Press 0 button for the arcade.
# well done! your 4* costa del sol holiday or £5000 await collection. call 09050090044 now toclaim. sae, tcs, pobox334, stockport, sk38xh, cost£1.50/pm, max10mins   |    well done! your 4 star holiday on the Costa del Sol or £5000 waiting to be picked up. Call 09050090044 now. Sae, tcs, pobox334, stockport, sk38xh, cost £1.50 / pm, max10min
# bored housewives! chat n date now! 0871750.77.11! bt-national rate 10p/min only from landlines!   |    bored housewives! Chat now n date! 0871750.77.11! bt country rate 10p / min only from landlines!
# you have won a guaranteed £200 award or even £1000 cashto claim ur award call free on 08000407165 (18+) 2 stop getstop on 88222 php   |    You have won a guaranteed £200 bonus or even £1,000 cash to claim our free call on 08000407165 (18 +) 2 stop getstop on 88222 php
# summers finally here! fancy a chat or flirt with sexy singles in yr area? to get matched up just reply summer now. free 2 join. optout txt stop help08714742804   |    Summer finally here! Fancy a chat or flirt with sexy singles in yr area? to be matched, just reply summer now. free 2 join. optout txt stop help08714742804
# u 447801259231 have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who thinks ur so special-call on 09058094597   |    u 447801259231 have a secret admirer looking for 2. Get in touch with u-find out who they r * reveal who our so special call is: 09058094597
# bought one ringtone and now getting texts costing 3 pound offering more tones etc   |    bought a ringtone and now got texts that cost £3 and offered more tones etc.
# last chance! claim ur £150 worth of discount vouchers today! text shop to 85023 now! savamob, offers mobile! t cs savamob pobox84, m263uz. £3.00 sub. 16   |    last chance! now discount vouchers worth £150! textshop on 85023! savamob, offers mobile! t cs savamob pobox84, m263uz. £3.00 sub. 16
# wow! the boys r back. take that 2007 uk tour. win vip tickets & pre-book with vip club. txt club to 81303. trackmarque ltd info@vipclub4u.   |    wow! the young r back. take this UK tour. win vip tickets & pre-book with vip club. txt club to 81303. trackmarque ltd info @ vipclub4u.
# u have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who thinks ur so special-call on 09058094599   |    u Do you have a secret admirer looking for 2, make contact with u-find who they r * reveal who thinks ur so special-call on 09058094599
# private! your 2003 account statement for 07973788240 shows 800 un-redeemed s. i. m. points. call 08715203649 identifier code: 40533 expires 31/10/04   |    private! Your account statement from 2003 under the number 07973788240 shows 800 unredeemed points. Call under the number 08715203649: 40533 expires on 31 / 10 / 04.
# buy space invaders 4 a chance 2 win orig arcade game console. press 0 for games arcade (std wap charge) see o2.co.uk/games 4 terms + settings. no purchase   |    buy Space Invaders 4 a chance 2 win orig arcade game console. press 0 for games arcade (std wap charge) see o2.co.uk / games 4 terms + settings. no purchase
# double mins and txts 4 6months free bluetooth on orange. available on sony, nokia motorola phones. call mobileupd8 on 08000839402 or call2optout/n9dx   |    double minutes and txts 4 6 months free bluetooth on orange. available on sony, nokia motorola phone. call mobileupd8 on 08000839402 or call2optout / n9dx
# moby pub quiz.win a £100 high street prize if u know who the new duchess of cornwall will be? txt her first name to 82277.unsub stop £1.50 008704050406 sp   |    moby pub quiz.win a £100 high street price if u know who the new Duchess of Cornwall will be? txt her first name to 82277.unsub stop £1.50 008704050406 sp
# want a new video phone? 750 anytime any network mins? half price line rental free text for 3 months? reply or call 08000930705 for free delivery   |    Want a new video phone? 750 anytime all network minutes? half price line rental free text for 3 months? answer or call 08000930705 for free delivery
# free entry to the gr8prizes wkly comp 4 a chance to win the latest nokia 8800, psp or £250 cash every wk.txt great to 80878 http//www.gr8prizes.com 08715705022   |    Free entry to the gr8prizes wkly comp 4 a chance to win the latest nokia 8800, psp or £250 cash each wk.txt great to 80878 http / / www.gr8prizes.com 08715705022
# money!!! you r a lucky winner ! 2 claim your prize text money 2 88600 over £1million to give away ! ppt150x3+normal text rate box403 w1t1jy   |    Money!!! You r one lucky winner! 2 claim your prize text money 2 88600 to give away over £1 million! ppt150x3 + normal text rate box403 w1t1jy
# loan for any purpose £500 - £75,000. homeowners + tenants welcome. have you been previously refused? we can still help. call free 0800 1956669 or text back 'help'   |    loan for any purpose £500- £75,000. Homeowners + tenants welcome. have you already been rejected? we can still help. call free 0800 1956669 or text back "Help"
# http//tms. widelive.com/index. wml?id=820554ad0a1705572711&first=true¡c c ringtone¡   |    http: / / tms. widelive.com / index. wml? id = 820554ad0a1705572711 & first = true "c"
# pdate_now - double mins and 1000 txts on orange tariffs. latest motorola, sonyericsson & nokia & bluetooth free! call mobileupd8 on 08000839402 or call2optout/!yhl   |    For the latest motorola, sonyericsson & nokia & bluetooth free, call mobileupd8 on 08000839402 or call2optout /!
# bloomberg -message center +447797706009 why wait? apply for your future http://careers. bloomberg.com   |    bloomberg -message center + 447797706009 Why wait? Apply for your future http: / / careers. bloomberg.com
# rct' thnq adrian for u text. rgds vatian   |    rct'thnq adrian for u text. rgds vatian
# dear voucher holder, to claim this weeks offer, at your pc please go to http://www.wtlp.co.uk/text. ts&cs apply.   |    Dear Voucher Holders, to take advantage of this weekly offer, please go to http: / / www.wtlp.de / text. ts & cs apply.
# 85233 free>ringtone!reply real   |    85233 free > Ringtone! Answer real
# life has never been this much fun and great until you came in. you made it truly special for me. i won't forget you! enjoy @ one gbp/sms   |    life has never been so much fun and was great until you came in. You made it something very special for me. I will not forget you! enjoy @ one gbp / sms
# urgent! last weekend's draw shows that you have won £1000 cash or a spanish holiday! call now 09050000332 to claim. t&c: rstm, sw7 3ss. 150ppm   |    Last weekend's draw shows you have won £1,000 cash or a holiday in Spain! Call 09050000332 now to make a claim. t & c: rstm, sw7 3ss. 150ppm
# your chance to be on a reality fantasy show call now = 08707509020 just 20p per min ntt ltd, po box 1327 croydon cr9 5wb 0870 is a national = rate call   |    Your chance to call a reality fantasy show now = 08707509020 just 20p per minute ntt ltd, po box 1327 croydon cr9 5wb 0870 is a national = rate call
# private! your 2003 account statement for 07808247860 shows 800 un-redeemed s. i. m. points. call 08719899229 identifier code: 40411 expires 06/11/04   |    private! Your account statement from 2003 for the number 07808247860 shows 800 unredeemed points. Call the number 08719899229: 40411 expires on 06 / 11 / 04.
# gent! we are trying to contact you. last weekends draw shows that you won a £1000 prize guaranteed. call 09064012160. claim code k52. valid 12hrs only. 150ppm   |    Sir! we are trying to contact you. last weekend shows that you have won a guaranteed prize of £1000. Call 09064012160.
# smsservices. for yourinclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe with stop, no extra charge. help 08702840625.comuk. 220-cm2 9ae   |    smsservices. for your inclusive text credits, pls goto www.comuk.net login = 3qxj9 unsubscribe with stop, no extra charge. help 08702840625.comuk.
# from next month get upto 50% more calls 4 ur standard network charge 2 activate call 9061100010 c wire3.net 1st4terms pobox84 m26 3uz cost £1.50 min mobcudb more   |    from next month up to 50% more calls 4 ur standard network rate 2 activate the call 9061100010 c wire3.net 1st4terms pobox84 m26 3uz costs £1.50 min mobcudb more
# u have a secret admirer. reveal who thinks u r so special. call 09065174042. to opt out reply reveal stop. 1.50 per msg recd. cust care 07821230901   |    u Have a secret admirer. Reveal who u r so special thing. call 09065174042 to reject the report. 1.50 per msg rec. cust care 07821230901
# double mins & 1000 txts on orange tariffs. latest motorola, sonyericsson & nokia with bluetooth free! call mobileupd8 on 08000839402 or call2optout/hf8   |    double min & 1000 txts at orange tariff. latest motorola, sonyericsson & nokia with bluetooth free! call mobileupd8 on 08000839402 or call2optout / hf8
# tddnewsletter@emc1.co.uk (more games from thedailydraw) dear helen, dozens of free games - with great prizeswith..   |    tddnewsletter @ emc1.co.uk (more games from thedailydraw) dear Helen, dozens of free games - with great prizes.
# please call 08712402578 immediately as there is an urgent message waiting for you   |    Please call immediately under the number 08712402578, because an urgent message is waiting for you.
# asked 3mobile if 0870 chatlines inclu in free mins. india cust servs sed yes. l8er got mega bill. 3 dont giv a shit. bailiff due in days. i o £250 3 want £800   |    asked 3mobile if 0870 chatlines incl. free minutes. india cust servs sed yes. l8er got mega bill. 3 dont giv a shit. bailiff due in day. i o £250 3 will £800
# had your contract mobile 11 mnths? latest motorola, nokia etc. all free! double mins & text on orange tariffs. text yes for callback, no to remove from records   |    Have you had your mobile contract for 11 months? latest motorola, nokia etc. all for free! double minutes & text on orange tariffs. Text yes for callback, no for removing records
# a £400 xmas reward is waiting for you! our computer has randomly picked you from our loyal mobile customers to receive a £400 reward. just call 09066380611   |    A £400 Christmas reward is waiting for you! Our computer has randomly selected you from our loyal mobile customers to receive a reward of £400. Simply call 09066380611.
# want explicit sex in 30 secs? ring 02073162414 now! costs 20p/min gsex pobox 2667 wc1n 3xx   |    want explicit sex in 30 seconds? Ring 02073162414 now! costs 20p / min gsex pobox 2667 wc1n 3xx
# congratulations ur awarded either £500 of cd gift vouchers & free entry 2 our £100 weekly draw txt music to 87066 tncs www.ldew.com1win150ppmx3age16   |    Congratulations: Either £500 CD vouchers & free entry 2 of our weekly draw of £100 txt music to 87066 tncs www.ldew.com1win150ppmx3age16
# themob> check out our newest selection of content, games, tones, gossip, babes and sport, keep your mobile fit and funky text wap to 82468   |    themob > Check out our latest selection of content, games, sounds, gossip, babes and sports, keep your phone fit and switch text to 82468
# private! your 2003 account statement for 07753741225 shows 800 un-redeemed s. i. m. points. call 08715203677 identifier code: 42478 expires 24/10/04   |    Your account statement from 2003 for the number 07753741225 shows 800 unredeemed points. Call 08715203677: 42478 expires on 24 / 10 / 04.
# private! your 2003 account statement for shows 800 un-redeemed s. i. m. points. call 08715203652 identifier code: 42810 expires 29/10/0   |    Your bank statement for 2003 shows 800 unredeemed points. Call 08715203652: 42810 expires on 29 / 10 / 0.
# new tones this week include: 1)mcfly-all ab.., 2) sara jorge-shock.. 3) will smith-switch.. to order follow instructions on next message   |    New sounds this week include: 1) mcfly-all ab.., 2) sara jorge-shock.. 3) will smith-switch.. to order follow instructions on next message
# loans for any purpose even if you have bad credit! tenants welcome. call noworriesloans.com on 08717111821   |    Loans for any purpose, even if you have bad credit! Tenants welcome. Call noworriesloans.com on 08717111821.
# private! your 2003 account statement for shows 800 un-redeemed s.i.m. points. call 08718738001 identifier code: 49557 expires 26/11/04   |    private! Your bank statement for 2003 shows 800 unredeemed s.i.m. points. Call 08718738001 with the identification: 49557 expires on 26 / 11 / 04.
# get a brand new mobile phone by being an agent of the mob! plus loads more goodies! for more info just text mat to 87021.   |    Get a brand new mobile phone by being an agent of the mob! plus lots of other goodies! just text 87021 for more information.
# jamster! to get your free wallpaper text heart to 88888 now! t&c apply. 16 only. need help? call 08701213186.   |    jamster! to get your free wallpaper with text heart on 88888 now! Only 16 applications. Need help? Call 08701213186.
# -pls stop bootydelious (32/f) is inviting you to be her friend. reply yes-434 or no-434 see her: www.sms.ac/u/bootydelious stop? send stop frnd to 62468   |    -pls stop bootydelious (32 / f) invites you to be her friend. answer yes-434 or no-434 see her: www.sms.ac / u / bootydelious stop? stop frnd send to 62468
# hot live fantasies call now 08707509020 just 20p per min ntt ltd, po box 1327 croydon cr9 5wb 0870..k   |    Call 08707509020 just 20p per minute ntt ltd, po box 1327 croydon cr9 5wb 0870.. k
# gr8 poly tones 4 all mobs direct 2u rply with poly title to 8007 eg poly breathe1 titles: crazyin, sleepingwith, finest, ymca :getzed.co.uk pobox365o4w45wq 300p   |    gr8 poly tones 4 all mobs direct 2u rply with poly title to 8007 eg poly breathe1 titles: crazyin, sleepingwith, finest, ymca: getzed.co.uk pobox365o4w45wq 300p
# congrats! 2 mobile 3g videophones r yours. call 09061744553 now! videochat wid ur mates, play java games, dload polyh music, noline rentl. bx420. ip4. 5we. 150pm   |    Congratulations! 2 mobile 3g videophones for yourselves. call now 09061744553! videochat wid ur mates, play java games, dload polyh music, noline rentl. bx420. ip4. 5we. 150pm
# xmas offer! latest motorola, sonyericsson & nokia & free bluetooth or dvd! double mins & 1000 txt on orange. call mobileupd8 on 08000839402 or call2optout/4qf2   |    Xmas offer! latest motorola, sonyericsson & nokia & free bluetooth or dvd! double mins & 1000 txt on orange. Call mobileupd8 on 08000839402 or call2optout / 4qf2.
# the current leading bid is 151. to pause this auction send out. customer care: 08718726270   |    The current top bid is 151st to suspend this auction. Customer Service: 08718726270
# want 2 get laid tonight? want real dogging locations sent direct 2 ur mob? join the uk's largest dogging network bt txting gravel to 69888! nt. ec2a. 31p.msg@150p   |    want 2 to be relocated tonight? want real dogging locations sent directly 2 ur mob? join the UK's largest dogging network bt txting kies to 69888! nt. ec2a. 31 p.msg @ 150p
# not heard from u4 a while. call 4 rude chat private line 01223585334 to cum. wan 2c pics of me gettin shagged then text pix to 8552. 2end send stop 8552 sam xxx   |    Call 4 rude chat private line 01223585334 to cum. wan 2c pictures of me gettin shagged then text pix to 852. 2end stop sending 8552 sam xxx
# this is the 2nd time we have tried to contact u. u have won the £1450 prize to claim just call 09053750005 b4 310303. t&cs/stop sms 08718725756. 140ppm   |    This is the second time we have tried to contact you and we have won the £1450 prize and just call 09053750005 b4 310303. t & cs / stop sms 08718725756.
# sms. ac jsco: energy is high, but u may not know where 2channel it. 2day ur leadership skills r strong. psychic? reply ans w/question. end? reply end jsco   |    sms. ac jsco: energy is high, but u may not know where 2channel it. 2day ur leadership skills r strong. Mental? Answer to w / question. End? Answer end jsco
# hi babe its chloe, how r u? i was smashed on saturday night, it was great! how was your weekend? u been missing me? sp visionsms.com text stop to stop 150p/text   |    hello baby be chloe, how r u? i was smashed on Saturday night, it was awesome! how was your weekend? u missed me? sp visionsms.com textstop to stop 150p / text
# you are chosen to receive a £350 award! pls call claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer.   |    You will be selected to receive a £350 reward! pls call 09066364311 to pick up your reward which you will receive as a valued mobile customer.
# network operator. the service is free. for t & c's visit 80488.biz   |    network operator. the service is free. for visiting t & c 80488.biz
# wamma get laid?want real doggin locations sent direct to your mobile? join the uks largest dogging network. txt dogs to 69696 now!nyt. ec2a. 3lp £1.50/msg.   |    wamma get laid? want real doggin locations sent direct to your mobile? join the uks largest dogging network. txt dogs to 69696 now! nyt. ec2a. 3lp £1.50 / msg.
# xmas & new years eve tickets are now on sale from the club, during the day from 10am till 8pm, and on thurs, fri & sat night this week. they're selling fast!   |    Tickets for Christmas and New Year's Eve are now available at the club, during the day from 10am to 8pm and on Thursdays, Fridays and Saturdays this week.
# for ur chance to win a £250 cash every wk txt: action to 80608. t's&c's www.movietrivia.tv custcare 08712405022, 1x150p/wk   |    For our chance to win £250 cash a week txt: action to 80608. t & c's www.movietrivia.tv 08712405022, 1x150p / wk
# i don't know u and u don't know me. send chat to 86688 now and let's find each other! only 150p/msg rcvd. hg/suite342/2lands/row/w1j6hl ldn. 18 years or over.   |    I do not know u and u do not know me. send chat now to 86688 and we will find each other! only 150p / msg rcvd. hg / suite342 / 2lands / row / w1j6hl should. 18 years or older.
# kit strip - you have been billed 150p. netcollex ltd. po box 1013 ig11 oja   |    Kit strip - you have billed 150. Netcollex ltd. po box 1013 ig11 oja
# fancy a shag? i do.interested? sextextuk.com txt xxuk suzy to 69876. txts cost 1.50 per msg. tncs on website. x   |    Fancy shag? i do.interested? sextextuk.com txt xxuk suzy to 69876. txts costs 1.50 per msg. tncs on the site. x
# you are guaranteed the latest nokia phone, a 40gb ipod mp3 player or a £500 prize! txt word: collect to no: 83355! ibhltd ldnw15h 150p/mtmsgrcvd18   |    You are guaranteed the latest Nokia phone, a 40GB iPod mp3 player or a prize of £500! txt word: collect to no: 83355! ibhltd ldnw15h 150p / mtmsgrcvd18
# had your mobile 10 mths? update to the latest camera/video phones for free. keep ur same number, get extra free mins/texts. text yes for a call   |    Did you have your phone 10 months? upgrade for free to the latest camera / video phones. Keep our same number, you get additional free minutes / SMS. Text yes for a call
# your free ringtone is waiting to be collected. simply text the password "mix" to 85069 to verify. get usher and britney. fml, po box 5249, mk17 92h. 450ppw 16   |    Your free ringtone is waiting to be collected. just send the password "mix" to 85069 to verify it. get usher and Brit. fml, po box 5249, mk17 92h. 450ppw 16
# get ur 1st ringtone free now! reply to this msg with tone. gr8 top 20 tones to your phone every week just £1.50 per wk 2 opt out send stop 08452810071 16   |    Get our first ringtone now for free! Answer to this msg with clay. gr8 top 20 tones to send to your phone every week just £1.50 per week 2 opt out stop 08452810071 16
# u have a secret admirer who is looking 2 make contact with u-find out who they r*reveal who thinks ur so special-call on 09058094565   |    u Do you have a secret admirer looking for 2, make contact with u-find who they r * reveal who thinks ur so special-call on 09058094565
# camera - you are awarded a sipix digital camera! call 09061221066 fromm landline. delivery within 28 days.   |    Camera - You will receive a sipix digital camera! Call 09061221066 from a landline. Delivery within 28 days.
# thanks for your ringtone order, reference t91. you will be charged gbp 4 per week. you can unsubscribe at anytime by calling customer services on 09057039994   |    Thank you for your ringtone order, reference t91. You will be charged gbp 4 per week. You can unsubscribe at any time by calling Customer Service on 09057039994.
# this is the 2nd time we have tried 2 contact u. u have won the £750 pound prize. 2 claim is easy, call 087187272008 now1! only 10p per minute. bt-national-rate.   |    This is the second time we have tried 2 contact u u have won the £750 pound prize. 2 claim is easy, call: 087187272008 now1! just 10p per minute. bt-national-rate.
# sms auction - a brand new nokia 7250 is up 4 auction today! auction is free 2 join & take part! txt nokia to 86021 now! hg/suite342/2lands row/w1j6hl   |    sms auction - a brand new nokia 7250 is 4 auctions today! auction is free 2 join & take part! txt nokia to 86021 now! hg / suite342 / 2lands row / w1j6hl
# santa calling! would your little ones like a call from santa xmas eve? call 09077818151 to book you time. calls1.50ppm last 3mins 30s t&c www.santacalling.com   |    call santa claus! would your little ones like a call from santa christmas eve? call 09077818151 to book your time. calls 1.50ppm last 3minutes 30s t & c www.santacalling.com
# todays voda numbers ending 7548 are selected to receive a $350 award. if you have a match please call 08712300220 quoting claim code 4041 standard rates app   |    Today's Voda numbers ending in 7548 will be selected to receive a prize of $350. If you have a match, please call using the Claim Code 4041 Standard Tariffs App.
# we tried to contact you re your response to our offer of a new nokia fone and camcorder hit reply or call 08000930705 for delivery   |    we have tried to contact you to get your response to our offer of a new Nokia phone and camcorder or give us a call to get a response.
# hi there, 2nights ur lucky night! uve been invited 2 xchat, the uks wildest chat! txt chat to 86688 now! 150p/msgrcvdhg/suite342/2lands/row/w1j6hl ldn 18yrs   |    hello, 2nights ur lucky night! uve been invited 2 xchat, the uks wildeste chat! txt chat to 86688 now! 150p / msgrcvdhg / suite342 / 2lands / row / w1j6hl
# reply to win £100 weekly! where will the 2006 fifa world cup be held? send stop to 87239 to end service   |    Win £100 a week! where will the 2006 FIFA World Cup be held? Stop sending 87239 to end the service
# spook up your mob with a halloween collection of a logo & pic message plus a free eerie tone, txt card spook to 8007 zed 08701417012150p per logo/pic   |    Spit your mob with a Halloween collection of logo & picture message plus free spooky sound, text card spooks at 8007 08701417012150p per logo / picture
# congrats! 2 mobile 3g videophones r yours. call 09063458130 now! videochat wid your mates, play java games, dload polyph music, noline rentl.   |    Congratulations! 2 mobile 3g video phones r his. call now 09063458130! videochat wid your mates, play java games, dload polyph music, noline rentl.
# got what it takes 2 take part in the wrc rally in oz? u can with lucozade energy! text rally le to 61200 (25p), see packs or lucozade.co.uk/wrc & itcould be u!   |    has what it takes to take part in the wrc rally in oz? u can use lucozade energy! Text rally le to 61200 (25p), see packages or lucozade.co.uk / wrc & itcould be u!
# congratulations - thanks to a good friend u have won the £2,000 xmas prize. 2 claim is easy, just call 08712103738 now! only 10p per minute. bt-national-rate   |    Congratulations - thanks to a good friend u won the £2,000 Christmas prize. 2 claims are simple, just call now on 08712103738! just 10p per minute. bt-national-rate
# hi, the sexychat girls are waiting for you to text them. text now for a great night chatting. send stop to stop this service   |    hello, the sexychat girls are waiting for you to text them. Text now for a great night chat. Stop sending to end this service
# goal! arsenal 4 (henry, 7 v liverpool 2 henry scores with a simple shot from 6 yards from a pass by bergkamp to give arsenal a 2 goal margin after 78 mins.   |    GOAL! Arsenal 4 (henry, 7 v liverpool 2 henry scored with a simple shot from 6 yards after a pass from Bergkamp a two-goal lead for Arsenal after 78 minutes.
# are you unique enough? find out from 30th august. www.areyouunique.co.uk   |    Are you unique enough? Find out on August 30 at www.areyouunique.co.uk
# please call our customer service representative on freephone 0808 145 4742 between 9am-11pm as you have won a guaranteed £1000 cash or £5000 prize!   |    Please call our customer service representative on 0808 145 4742 between 9am and 11pm as you have won a guaranteed cash prize of £1000 or £5000!
# had your mobile 10 mths? update to latest orange camera/video phones for free. save £s with free texts/weekend calls. text yes for a callback orno to opt out   |    Have you had your phone for 10 months? Update for free to the latest orange camera / video phones. Save £s with free texts / weekend calls.
# hmv bonus special 500 pounds of genuine hmv vouchers to be won. just answer 4 easy questions. play now! send hmv to 86688 more info:www.100percent-real.com   |    hmv bonus special 500 pounds genuine hmv vouchers amazing. just answer 4 simple questions. play now! send hmv to 86688 for more information: www.100percent-real.com
# congratulations ur awarded either a yrs supply of cds from virgin records or a mystery gift guaranteed call 09061104283 ts&cs www.smsco.net £1.50pm approx 3mins   |    Congratulations either on a stock of CDs of virgin records or on a guaranteed mystery gift call 09061104283 ts & cs www.smsco.net £13.50 approx 3min
# december only! had your mobile 11mths+? you are entitled to update to the latest colour camera mobile for free! call the mobile update co free on 08002986906   |    Only in December! did your phone have 11 months +? you are entitled to upgrade to the latest colour camera phone for free! call the free number 08002986906
# u’ve bin awarded £50 to play 4 instant cash. call 08715203028 to claim. every 9th player wins min £50-£500. optout 08718727870   |    u've been awarded £50 to play 4 Instant Cash. Call 08715203028. every 9th player wins min £50- £500. Optout 08718727870
# mobile club: choose any of the top quality items for your mobile. 7cfca1a   |    Mobile club: Choose one of the highest quality products for your mobile phone. 7cfca1a
# you have won a guaranteed £1000 cash or a £2000 prize. to claim yr prize call our customer service representative on 08714712379 between 10am-7pm cost 10p   |    You have won a guaranteed sum of £1000 in cash or a prize of £2000. To claim your prize, call our customer service representative on 08714712379 between 10am and 7pm.
# you are a winner u have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810   |    You are a winner u have been specially selected to receive 2 £1000 in cash or a 4 * holiday (flights included) speak to a live operator 2 to claim 0871277810810
# you have won a guaranteed £1000 cash or a £2000 prize. to claim yr prize call our customer service representative on 08714712394 between 10am-7pm   |    You have won a guaranteed sum of £1000 in cash or a prize of £2000. To claim your prize, call our customer service representative on 08714712394 between 10am and 7pm.
# you have won a guaranteed £1000 cash or a £2000 prize.to claim yr prize call our customer service representative on   |    You have won a guaranteed prize of £1000 in cash or £2000. Call our customer service representative to claim your prize.
# reminder: you have not downloaded the content you have already paid for. goto http://doit. mymoby. tv/ to collect your content.   |    Reminder: You have not downloaded the content you have already paid for. Visit http: / / doit. mymoby. tv / to collect your content.
# good luck! draw takes place 28th feb 06. good luck! for removal send stop to 87239 customer services 08708034412   |    Good luck! Draw will take place on February 28th 06. good luck! stop for the removal send to 87239 customer service 08708034412
# freemsg you have been awarded a free mini digital camera, just reply snap to collect your prize! (quizclub opt out? stop 80122300p/wk sp:rwm ph:08704050406)   |    freemsg You have received a free mini digital camera, just reply Snap to get your prize! (Quizclub opt out? Stop 80122300p / wk sp: rwm ph: 08704050406)
# welcome! please reply with your age and gender to begin. e.g 24m   |    welcome! please reply to start with your age and gender. e.g. 24m
# free for 1st week! no1 nokia tone 4 ur mob every week just txt nokia to 8007 get txting and tell ur mates www.getzed.co.uk pobox 36504 w45wq norm150p/tone 16+   |    free for week 1! no1 nokia ton 4 ur mob every week just txt nokia to 8007 get txting and tell ur mates www.getzed.co.uk pobox 36504 w45wq norm150p / tone 16 +
# congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! c suprman v, matrix3, starwars3, etc all 4 free! bx420-ip4-5we. 150pm. dont miss out!   |    Congratulations! 1 year cinema pass for 2 is yours. Call now 09061209465! c suprman v, matrix3, starwars3, etc. all 4 for free! bx420-ip4-5we. 150 pm. do not miss!
# what do u want for xmas? how about 100 free text messages & a new video phone with half price line rental? call free now on 0800 0721072 to find out more!   |    what do you want for Christmas? how about 100 free SMS messages and a new video phone at half price? Call now for free on 0800 0721072 to find out more!
# get a free mobile video player free movie. to collect text go to 89105. its free! extra films can be ordered t's and c's apply. 18 yrs only   |    get a free mobile video player for free films. to collect text go to 89105. it's free! additional movies can be ordered t's and c's applicable. only 18 years
# rock yr chik. get 100's of filthy films &xxx pics on yr phone now. rply filth to 69669. saristar ltd, e14 9yt 08701752560. 450p per 5 days. stop2 cancel   |    rock yr chik. now 100's dirty movies & xxx photos on yr phone. rply dirt to 69669. saristar ltd, e14 9yt 08701752560. 450p per 5 days. stop2 cancel
# urgent! we are trying to contact u. todays draw shows that you have won a £800 prize guaranteed. call 09050003091 from land line. claim c52. valid 12hrs only   |    Today's draw shows you have won a guaranteed prize of £800, so call 09050003091 from the mainland.
# reminder from o2: to get 2.50 pounds free call credit and details of great offers pls reply 2 this text with your valid name, house no and postcode   |    Reminder from o2: to receive £2.50 free call credit and details of great offers, reply 2 with your valid name, house number and postcode
# xclusive@clubsaisai 2morow 28/5 soiree speciale zouk with nichols from paris.free roses 2 all ladies !!! info: 07946746291/07880867867   |    xclusive @ clubsaisai 2morow 28 / 5 soiree speciale zouk with nichols from paris.free roses 2 all ladies!!! info: 07946746291 / 07880867867
# themob>yo yo yo-here comes a new selection of hot downloads for our members to get for free! just click & open the next link sent to ur fone...   |    themob > yo yo yo-here comes a new selection of hot downloads that our members can download for free! Just click and open the next link that will be sent to us...
# you have 1 new message. please call 08712400200.   |    You have 1 new message. Please call 08712400200.
# had your mobile 11mths ? update for free to oranges latest colour camera mobiles & unlimited weekend calls. call mobile upd8 on freefone 08000839402 or 2stoptxt   |    Have you had your phone for 11 months? Update to Orange's latest colour camera phones for free & unlimited weekend calls by calling mobile upd8 on the free number 08000839402 or 2stoptxt.
# win: we have a winner! mr. t. foley won an ipod! more exciting prizes soon, so keep an eye on ur mobile or visit www.win-82050.co.uk   |    win: we have a winner! mr. t. foley has won an ipod! more exciting prizes coming soon, so keep an eye on your mobile or visit www.win-82050.co.uk
# great news! call freefone 08006344447 to claim your guaranteed £1000 cash or £2000 gift. speak to a live operator now!   |    Good news! Call the free number 08006344447 to claim your guaranteed £1,000 cash or £2,000 gift. Talk to a live operator now!
# free unlimited hardcore porn direct 2 your mobile txt porn to 69200 & get free access for 24 hrs then chrgd@50p per day txt stop 2exit. this msg is free   |    free unlimited hardcore porn direct 2 your mobile txt porn to 69200 & get free access for 24 hours then chrgd @ 50p per day txt stop 2exit. this msg is free
# want the latest video handset? 750 anytime any network mins? half price line rental? reply or call 08000930705 for delivery tomorrow   |    Want the latest video handset? 750 anytime all network minutes? at half price line rental? answer or call 08000930705 for delivery tomorrow
# sunshine hols. to claim ur med holiday send a stamped self address envelope to drinks on us uk, po box 113, bray, wicklow, eire. quiz starts saturday! unsub stop   |    sunshine hols. to claim ur med holiday send a stamped envelope with self address to drinks on us uk, po box 113, bray, wicklow, eire. quiz starts on saturday! unsub stop
# spjanuary male sale! hot gay chat now cheaper, call 08709222922. national rate from 1.5p/min cheap to 7.8p/min peak! to stop texts call 08712460324 (10p/min)   |    spjanuary male sale! hot gay chat now cheaper, call 08709222922. national rate from 1.5p / min cheap to 7.8p / min peak! to stop texts call 08712460324 (10p / min)
# you 07801543489 are guaranteed the latests nokia phone, a 40gb ipod mp3 player or a £500 prize! txt word:collect to no:83355! tc-llc ny-usa 150p/mt msgrcvd18+   |    You are guaranteed the latest Nokia phone, a 40GB iPod mp3 player or a £500 prize! txt Word: collect on No: 83355! tc-llc ny-usa 150p / mt msgrcvd18 +
# marvel mobile play the official ultimate spider-man game (£4.50) on ur mobile right now. text spider to 83338 for the game & we ll send u a free 8ball wallpaper   |    Marvel Mobile is now playing the official Ultimate Spider-Man game (£4.50) on our mobile. Text Spider to 83338 for the game & we'll send you a free 8ball wallpaper
# you have been specially selected to receive a 2000 pound award! call 08712402050 before the lines close. cost 10ppm. 16+. t&cs apply. ag promo   |    They have been specially selected to receive a reward of £2,000! Call 08712402050 before the lines close. cost 10ppm. 16 +. t & cs apply. ag promo
# free entry in 2 a weekly comp for a chance to win an ipod. txt pod to 80182 to get entry (std txt rate) t&c's apply 08452810073 for details 18+   |    Free entry for 2 people per week to get a chance to win an iPod. txt pod to 80182 to get entry (std txt rate) t & c's apply 08452810073 for details 18 +
# 18 days to euro2004 kickoff! u will be kept informed of all the latest news and results daily. unsubscribe send get euro stop to 83222.   |    With 18 days to go until the start of Euro2004! u will be kept up to date with all the latest news and results on a daily basis.
# you can stop further club tones by replying "stop mix" see my-tone.com/enjoy. html for terms. club tones cost gbp4.50/week. mfl, po box 1146 mk45 2wt (2/3)   |    You can stop more club sounds by answering "Stop Mix," see my-tone.com / enjoy. html for terms. Club sounds cost gbp4.50 / week. mfl, po box 1146 mk45 2wt (2 / 3)
# lookatme!: thanks for your purchase of a video clip from lookatme!, you've been charged 35p. think you can do better? why not send a video in a mmsto 32323.   |    lookatme!: thank you for buying a video clip from lookatme!, you were charged 35p. Think you can do better? why not send a video in a mmsto 32323.
# reply with your name and address and you will receive by post a weeks completely free accommodation at various global locations www.phb1.com ph:08700435505150p   |    Fill in your name and address and you will receive a week's free accommodation by post at various global locations www.phb1.com Tel.: 08700435505150p
# private! your 2003 account statement for shows 800 un-redeemed s. i. m. points. call 08715203694 identifier code: 40533 expires 31/10/04   |    private! Your bank statement for 2003 shows 800 unredeemed points. Call 08715203694 with the ID: 40533 expires on 31.10.04.
# dear voucher holder, 2 claim this weeks offer, at your pc go to http://www.e-tlp.co.uk/expressoffer ts&cs apply.2 stop texts txt stop to 80062.   |    Dear coupon holder, 2 claims in this week's offer, on your PC go to http: / / www.e-tlp.de / expressoffer ts & cs apply.2 Stop texts txt stop to 80062.
# hack chat. get backdoor entry into 121 chat rooms at a fraction of the cost. reply neo69 or call 09050280520, to subscribe 25p pm. dps, bcm box 8027 ldn, wc1n3xx   |    hack chat. get backdoor entry to 121 chatrooms at a fraction of the cost. answer neo69 or call 09050280520 to subscribe to 25p pm. dps, bcm box 8027 ought, wc1n3xx
# winner!! as a valued network customer you have been selected to receivea £900 prize reward! to claim call 09061701461. claim code kl341. valid 12 hours only.   |    Winner!! as a valued network customer you were selected to receive a £900 reward! to call 09061701461.
# dear dave this is your final notice to collect your 4* tenerife holiday or #5000 cash award! call 09061743806 from landline. tcs sae box326 cw25wx 150ppm   |    dear dave, this is your last message to pick up your 4 * Tenerife holiday or cash prize # 5000! call 09061743806 from landline tcs sae box326 cw25wx 150ppm
# tbs/persolvo. been chasing us since sept for£38 definitely not paying now thanks to your information. we will ignore them. kath. manchester.   |    tbs / persolvo. chase us since sept for £38 and pay now thanks to your information. we will ignore it. cath. manchester.
# ...
# sorry i missed your call let's talk when you have the time. i'm on 07090201529   |    Sorry, I missed your call, let's talk if you have the time. i am on 07090201529
# get the official england poly ringtone or colour flag on yer mobile for tonights game! text tone or flag to 84199. optout txt eng stop box39822 w111wx £1.50   |    Get the official English poly ringtone or color flag on yer mobile for tonights game! Text tone or flag to 84199. optout txt tight stop box39822 w111wx £1.50
# i don't know u and u don't know me. send chat to 86688 now and let's find each other! only 150p/msg rcvd. hg/suite342/2lands/row/w1j6hl ldn. 18 years or over.   |    I do not know u and u do not know me. send chat now to 86688 and we will find each other! only 150p / msg rcvd. hg / suite342 / 2lands / row / w1j6hl should. 18 years or older.
# want to funk up ur fone with a weekly new tone reply tones2u 2 this text. www.ringtones.co.uk, the original n best. tones 3gbp network operator rates apply   |    want to spark our phone with a weekly new tone response tones2u 2 in this text. www.ringtones.co.uk, the original n best. tones 3gbp network operator tariffs apply
# natalja (25/f) is inviting you to be her friend. reply yes-440 or no-440 see her: www.sms.ac/u/nat27081980 stop? send stop frnd to 62468   |    natalja (25 / f) invites you to be her girlfriend. answer yes-440 or no-440 see www.sms.ac / u / nat27081980 stop? send stop frnd to 62468
# do you want a new video handset? 750 anytime any network mins? half price line rental? camcorder? reply or call 08000930705 for delivery tomorrow   |    Want a new video handset? 750 anytime all network minutes? half price rental? Camcorder? Answer or call 08000930705 for delivery tomorrow
# message important information for o2 user. today is your lucky day! 2 find out why log onto http://www.urawinner.com there is a fantastic surprise awaiting you   |    Message important information for o2 users. Today is your lucky day! 2 Find out why a fantastic surprise awaits you at http: / / www.urawinner.com
# wanna get laid 2nite? want real dogging locations sent direct to ur mobile? join the uk's largest dogging network. txt park to 69696 now! nyt. ec2a. 3lp £1.50/msg   |    wanna get laid 2nite? want real dogging locations sent direct to ur mobile? join the UK's largest dogging network. txt park to 69696 now! nyt. ec2a. 3lp £1.50 / msg
# 3 free tarot texts! find out about your love life now! try 3 for free! text chance to 85555 16 only! after 3 free, msgs £1.50 each   |    3 free tarot texts! Learn about your love life now! Try 3 free! text chance only on 85555 16! after 3 free, msgs £1.50 apiece
# congrats! nokia 3650 video camera phone is your call 09066382422 calls cost 150ppm ave call 3mins vary from mobiles 16+ close 300603 post bcm4284 ldn wc1n3xx   |    Congratulations! nokia 3650 video camera phone is your call 09066382422 calls cost 150ppm ave call 3minutes vary from mobile phones 16 + close 300603 post bcm4284 wc1n3xx
# great new offer - double mins & double txt on best orange tariffs and get latest camera phones 4 free! call mobileupd8 free on 08000839402 now! or 2stoptxt t&cs   |    Great new offer - double minutes & double text messages on the best orange tariffs and get the latest camera phones 4 for free! Call mobileupd8 now for free on 08000839402! or 2stoptxt t & cs
# dear u've been invited to xchat. this is our final attempt to contact u! txt chat to 86688 150p/msgrcvdhg/suite342/2lands/row/w1j6hl ldn 18 yrs   |    dear u've been invited to xchat. this is our last attempt to contact u! txt chat to 86688 150p / msgrcvdhg / suite342 / 2lands / row / w1j6hl 18 yrs.
# cashbin.co.uk (get lots of cash this weekend!) www.cashbin.co.uk dear welcome to the weekend we have got our biggest and best ever cash give away!! these..   |    cashbin.co.uk (get a lot of money this weekend!) www.cashbin.co.uk Welcome to the weekend, we have our biggest and best cash give-away!! this..
# call 09094100151 to use ur mins! calls cast 10p/min (mob vary). service provided by aom, just gbp5/month. aom box61,m60 1er until u stop. ages 18+ only!   |    Call 09094100151 to use ur min! calls cast at 10p / min (mob vary). Service from aom, only gbp5 / month. aom box61, m60 1er to u stop. only from 18 years!
# hot live fantasies call now 08707500020 just 20p per min ntt ltd, po box 1327 croydon cr9 5wb 0870 is a national rate call   |    hot live fantasies now call 08707500020 just 20p per minute ntt ltd, po box 1327 croydon cr9 5wb 0870 is a national tariff call
# your free ringtone is waiting to be collected. simply text the password "mix" to 85069 to verify. get usher and britney. fml, po box 5249, mk17 92h. 450ppw 16   |    Your free ringtone is waiting to be collected. just send the password "mix" to 85069 to verify it. get usher and Brit. fml, po box 5249, mk17 92h. 450ppw 16
# recpt 1/3. you have ordered a ringtone. your order is being processed...   |    recpt 1 / 3. you have ordered a ringtone. Your order will be processed...
# 3. you have received your mobile content. enjoy   |    3. You have received your mobile content. Enjoy
# show ur colours! euro 2004 2-4-1 offer! get an england flag & 3lions tone on ur phone! click on the following service message for info!   |    Euro 2004 2-4-1 Offer! Get an English flag & 3lions sound on your phone! Click on the following service message for more information!
# call germany for only 1 pence per minute! call from a fixed line via access number 0844 861 85 85. no prepayment. direct access!   |    call germany for only 1 cent per minute! call from a landline to 0844 861 85 85. No advance payment. direct access!
# for ur chance to win a £250 wkly shopping spree txt: shop to 80878. t's&c's www.txt-2-shop.com custcare 08715705022, 1x150p/wk   |    For your chance at a £250 shopping spree txt: shop to 808788. t & c's www.txt-2-shop.com, 08715705022, 1x150p / wk
# no 1 polyphonic tone 4 ur mob every week! just txt pt2 to 87575. 1st tone free ! so get txtin now and tell ur friends. 150p/tone. 16 reply hl 4info   |    no 1 polyphonic tone 4 ur mob every week! just txt pt2 to 87575. 1. tone free! so get txtin now and tell your friends. 150p / ton. 16 replies hl 4info
# congrats 2 mobile 3g videophones r yours. call 09063458130 now! videochat wid ur mates, play java games, dload polyph music, noline rentl. bx420. ip4. 5we. 150p   |    Congratulations 2 mobile 3g video phones r his. call now 09063458130! videochat wid ur mates, play java games, dload polyph music, noline rentl. bx420. ip4. 5we. 150p
# todays vodafone numbers ending with 4882 are selected to a receive a £350 award. if your number matches call 09064019014 to receive your £350 award.   |    Today's Vodafone numbers ending in 4882 will be selected to receive a prize of £350. If your number matches 09064019014, you will receive your prize of £350.
# fantasy football is back on your tv. go to sky gamestar on sky active and play £250k dream team. scoring starts on saturday, so register now!sky opt out to 88088   |    Fantasy football is back on your television. go to Sky Gamestar on Sky Active and play £250k dream team. the scoring starts on Saturday, so sign up now! sky opt out to 88088
# u can win £100 of music gift vouchers every week starting now txt the word draw to 87066 tscs www.idew.com skillgame, 1winaweek, age16. 150ppermesssubscription   |    u Every week, music gift vouchers worth £100 can be won, which can now be raffled off at 87066 tsc. www.idew.com Skillgame, 1winaweek, from the age of 16.
# free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005. text fa to 87121 to receive entry question(std txt rate)t&c's apply 08452810075over18's   |    Free entry to 2 a wkly comp to win fa cup final tkts 21 May 2005. text fa to 87121 to receive entry question (std txt rate) t & c's apply 08452810075over18's
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-77505c416487> in <cell line: 10>()
#       9
#      10 for message in df_train[df_train['Category'] == 'spam']['Message']:
# ---> 11   new_msg = back_translation_aug.augment(message)[0]
#      12   print(message, '  |   ', new_msg)
#      13   translated_texts.append(new_msg)
#
# /usr/local/lib/python3.10/dist-packages/nlpaug/base_augmenter.py in augment(self, data, n, num_thread)
#      96             elif self.__class__.__name__ in ['AbstSummAug', 'BackTranslationAug', 'ContextualWordEmbsAug', 'ContextualWordEmbsForSentenceAug']:
#      97                 for _ in range(aug_num):
# ---> 98                     result = action_fx(clean_data)
#      99                     if isinstance(result, list):
#     100                         augmented_results.extend(result)
#
# /usr/local/lib/python3.10/dist-packages/nlpaug/augmenter/word/back_translation.py in substitute(self, data, n)
#      68             return data
#      69
# ---> 70         augmented_text = self.model.predict(data)
#      71         return augmented_text
#      72
#
# /usr/local/lib/python3.10/dist-packages/nlpaug/model/lang_models/machine_translation_transformers.py in predict(self, texts, target_words, n)
#      37
#      38     def predict(self, texts, target_words=None, n=1):
# ---> 39         src_translated_texts = self.translate_one_step_batched(texts, self.src_tokenizer, self.src_model)
#      40         tgt_translated_texts = self.translate_one_step_batched(src_translated_texts, self.tgt_tokenizer, self.tgt_model)
#      41
#
# /usr/local/lib/python3.10/dist-packages/nlpaug/model/lang_models/machine_translation_transformers.py in translate_one_step_batched(self, data, tokenizer, model)
#      60                 input_ids, attention_mask = batch
#      61
# ---> 62                 translated_ids_batch = model.generate(
#      63                     input_ids=input_ids, attention_mask=attention_mask,
#      64                     max_length=self.max_length
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, **kwargs)
#    1625             )
#    1626             # 13. run beam search
# -> 1627             return self.beam_search(
#    1628                 input_ids,
#    1629                 beam_scorer,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2930             model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2931
# -> 2932             outputs = self(
#    2933                 **model_inputs,
#    2934                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/fsmt/modeling_fsmt.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1218             use_cache = False
#    1219
# -> 1220         outputs = self.model(
#    1221             input_ids,
#    1222             inputs_embeds=inputs_embeds,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/fsmt/modeling_fsmt.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, use_cache, output_attentions, output_hidden_states, inputs_embeds, decoder_inputs_embeds, return_dict)
#    1124
#    1125         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1126         decoder_outputs = self.decoder(
#    1127             decoder_input_ids,
#    1128             encoder_outputs[0],
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/fsmt/modeling_fsmt.py in forward(self, input_ids, encoder_hidden_states, encoder_padding_mask, decoder_padding_mask, decoder_causal_mask, head_mask, inputs_embeds, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     801             layer_state = past_key_values[idx] if past_key_values is not None else None
#     802
# --> 803             x, layer_self_attn, layer_past, layer_cross_attn = decoder_layer(
#     804                 x,
#     805                 encoder_hidden_states,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/fsmt/modeling_fsmt.py in forward(self, x, encoder_hidden_states, encoder_attn_mask, layer_state, causal_mask, layer_head_mask, cross_attn_layer_head_mask, decoder_padding_mask, output_attentions)
#     651         x = self.activation_fn(self.fc1(x))
#     652         x = nn.functional.dropout(x, p=self.activation_dropout, training=self.training)
# --> 653         x = self.fc2(x)
#     654         x = nn.functional.dropout(x, p=self.dropout, training=self.training)
#     655         x = residual + x
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
len(translated_texts)
# Out:
# 301

# %%
translations_df = pd.DataFrame({"Message": translated_texts, "Category": "spam"})
df_train_translations = pd.concat([df_train, translations_df])

# %%
df_train_translations["Category"].value_counts()
# Out:
# ham     3609
# spam     871
# Name: Category, dtype: int64

# %%
df_train_translations["Message"] = df_train_translations["Message"].str.lower()

# %%
# perform TFIDF
X_train_trans_tfidf = tfidf.transform(df_train_translations["Message"])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


lr = LogisticRegression()
lr.fit(X_train_trans_tfidf, df_train_translations["Category"])
print(classification_report(y_test, lr.predict(X_test_tfidf)))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99      1216
#         spam       0.96      0.86      0.91       177
#
#     accuracy                           0.98      1393
#    macro avg       0.97      0.93      0.95      1393
# weighted avg       0.98      0.98      0.98      1393

# %% [markdown]
# # Text augmentation using simple EDA: Easy Data Augmentation Techniques
#
# Code from paper authors: https://github.com/jasonwei20/eda_nlp
#
# Simple Data Augmentatons Techniques are:
# - SR : Synonym Replacement
# - RD : Random Deletion
# - RS : Random Swap
# - RI : Random Insertion

# %% [markdown]
# ### EDA

# %%
# %%capture
# !pip install numpy requests
# !pip install -U nltk
import nltk
nltk.download('wordnet')

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_train.head(2)
# Out:
#                                                 Message Category
# 1280  waiting 4 my tv show 2 start lor... u leh stil...      ham
# 1658  s:-)if we have one good partnership going we w...      ham

# %%
# Adapted from https://github.com/jasonwei20/eda_nlp

"""
Take an input sentence,
an alpha_sr parameter (controls the number of synonym replacement operations)
an alpha_ri parameter (controls the number of random insertion operations)
an alpha_rs parameter (controls the number of random swap operations)
an alpha_rd parameter (controls the number of random deletion operations)
"""

import random
from nltk.corpus import wordnet


def get_synonyms(word):
    """Get synonyms of a word from WordNet."""
    synonyms = wordnet.synsets(word)
    if synonyms:
        words = [lem.name() for lem in synonyms[0].lemmas()]
        return words
    else:
        return []


def replace_with_synonyms(message, alpha_sr=0.1):
    """
    Randomly choose n words from the sentence that are not stop words.
    Replace each of these words with one of its synonyms chosen at random.
    """
    words = message.split(" ")
    num_words = len(words)
    n = max(1, int(alpha_sr * num_words))
    for _ in range(n):
        word_to_replace = random.choice(words)
        synonyms = get_synonyms(word_to_replace)
        if synonyms:
            words[words.index(word_to_replace)] = random.choice(synonyms)
    return " ".join(words)


def random_deletion(message, alpha_rd=0.1):
    """
    For each word in the sentence, randomly remove it with probability p
    """
    words = message.split(" ")
    num_words = len(words)
    n = max(1, int(alpha_rd * num_words))
    for _ in range(n):
        if len(words) > 1:
            del words[random.randint(0, len(words) - 1)]
    return " ".join(words)


def random_insertion(message, alpha_ri=0.1):
    """
    Find a random synonym of a random word in the sentence that is not a stop word.
    Insert that synonym into a random position in the sentence. Do this n times.
    """
    words = message.split(" ")
    num_words = len(words)
    n = max(1, int(alpha_ri * num_words))
    for _ in range(n):
        synonym_word = random.choice(words)
        synonyms = get_synonyms(synonym_word)
        if synonyms:
            words.insert(random.randint(0, len(words)), random.choice(synonyms))
    return " ".join(words)


def random_swap(message, alpha_rs=0.1):
    """
    Randomly choose two words in the sentence and swap their positions.
    Do this n times.
    """
    words = message.split(" ")
    num_words = len(words)
    n = max(1, int(alpha_rs * num_words))
    for _ in range(n):
        if len(words) > 1:
            idx1, idx2 = random.sample(range(len(words)), 2)
            words[idx1], words[idx2] = words[idx2], words[idx1]
    return " ".join(words)

# %%
augmented_texts = []
for message in df_train[df_train["Category"] == "spam"]["Message"]:
    message = replace_with_synonyms(message)
    message = random_deletion(message)
    message = random_insertion(message)
    augmented_text = random_swap(message)
    print(message, "  |   ", augmented_text)
    augmented_texts.append(augmented_text)
# Out:
# winner!! as a valued network client you have been selected to receivea £900 to claim call 09061701461. claim code kl341. valid 12 be hours only.   |    selected as a valued network client you have been winner!! to receivea £900 12 claim call 09061701461. claim code kl341. valid to be hours only.
# your account has been credited 500 free text messages. to activate, just txt the word: credit credit to no: 80488 www.80488.biz   |    account your has been credited 500 free text messages. to activate, just txt credit word: the credit to no: 80488 www.80488.biz
# urgent! we are trying to contact u todays draw shows that have won a £800 prize guaranteed. call from land line. claim U j89. po box245c2150pm   |    todays we are trying to prize u urgent! draw shows that have won a £800 contact guaranteed. call from land line. claim U j89. po box245c2150pm
# want to operator funk up ur fone with weekly new tone reply tones2u 2 this text. www.ringtones.co.uk, the original n best. 3gbp network operator rates employ apply   |    want to operator funk up ur fone operator weekly new tone reply tones2u 2 this text. www.ringtones.co.uk, the original n rates 3gbp network with best. employ apply
# thanks for your ringtone order, reference delight number x49. your mobile will be charged 4.50. should your tone non delight call customer services from: [colour=red]text[/colour]txtstar   |    thanks for your ringtone order, reference delight services x49. your mobile non be charged 4.50. should your tone will delight call customer number from: [colour=red]text[/colour]txtstar
# not heard from u4 a while. call me am here all knickerbockers night with just knickers on. me beg for it like u did last time 01223585236 xx luv nikiyu4.net all   |    not am all u4 a while. heard me call here from knickerbockers night with just knickers on. me beg for it like u did last time 01223585236 xx luv nikiyu4.net all
# 62735=£450 uk break accommodationvouchers terms & conditions apply. 2 claim you mustprovide your claim number which is 15541   |    2 uk break accommodationvouchers terms & conditions apply. 62735=£450 claim you mustprovide your claim number which is 15541
# sms services. for inclusive text credits, pls goto www.comuk.net login= ***** unsubscribe with stop. no extra charge. help:08700469649. po box420. 5we   |    sms services. for inclusive text credits, pls www.comuk.net goto extra ***** unsubscribe with stop. no login= charge. help:08700469649. po box420. 5we
# you are a winner you have been specially select to receive £1000 cash or a £2000 award. speak a operator to claim call 087147123779am-7pm. cost cost 10p   |    a are a winner you 087147123779am-7pm. been specially select to receive £1000 cash or a £2000 award. speak you operator to claim call have cost cost 10p
# free top ringtone -sub to weekly ringtone-get 1st week free-send subpoly to 81618-?3 week-stop sms-08718727870   |    free sms-08718727870 ringtone -sub to weekly ringtone-get 1st week free-send subpoly to 81618-?3 week-stop top
# someone conacted our dating be service and entered your phone they fancy you!to find out be who it is call from landline 09111030116. pobox12n146tf15   |    someone conacted our dating be service and fancy your phone they entered you!to pobox12n146tf15 out be who it is call from landline 09111030116. find
# freemsg hi baby wow got a new cam moby. wanna a pic? or fancy a chat?im w8in 4utxt / rply schmoose to 82242 hlp 08712317606 msg150p 2rcv   |    freemsg hi baby wow got a new cam moby. wanna rply pic? or hlp a chat?im w8in 4utxt / a schmoose to 82242 fancy 08712317606 msg150p 2rcv
# sms services services for your inclusive text credits pls gotto www.comuk.net charge login 3qxj9 unsubscribe with stop extra charge help comuk.220cm2 9ae   |    sms services services your for inclusive text credits pls gotto www.comuk.net charge login charge unsubscribe with stop extra 3qxj9 help comuk.220cm2 9ae
# if you don't, your prize will to another customer. t&c at www.t-c.biz 18+ 150p/min polo ltd suite 373 atomic_number_85 london w1j 6hl please call back busy   |    if you don't, your prize will back another customer. t&c at www.t-c.biz 18+ 150p/min 373 ltd suite polo atomic_number_85 london w1j 6hl please call to busy
# i don't u and u don't know me. send chat to now and let's find each other! only 150p/msg rcvd. hg/suite342/2lands/row/w1j6hl ldn. 18 years uracil or over.   |    i don't u and u don't know me. and chat to now send let's find each other! only 150p/msg rcvd. hg/suite342/2lands/row/w1j6hl ldn. uracil years 18 or over.
# free entry in 2 a weekly comp for a chance to angstrom win Associate_in_Nursing ipod. txt seedcase to 80182 get (std txt rate) t&c's 08452810073 for details 18+   |    free entry to 2 a weekly comp for a chance to angstrom win Associate_in_Nursing ipod. txt seedcase in 80182 get (std txt rate) t&c's 08452810073 for details 18+
# 08714712388 between 10am-7pm cost   |    08714712388 between cost 10am-7pm
# uracil have a secret admirer on is looking 2 make contact with u-find out who they r*reveal thinks ur so special-call on 09058094594   |    uracil ur on secret admirer a is looking 2 make contact with u-find out who they r*reveal thinks have so special-call on 09058094594
# dear voucher holder have your next meal on us. use followers link on pc 2 enjoy unity a 2 4 unity dining experiencehttp://www.vouch4me.com/etlp/dining.asp   |    dear voucher holder link your next meal on us. use followers have 4 pc 2 enjoy unity a 2 on unity dining experiencehttp://www.vouch4me.com/etlp/dining.asp
# thnq adrian for u text. rgds vatian   |    thnq adrian for vatian text. rgds u
# our brand new mobile music service is now live. the free music player will arrive shortly. just install your phone brand_name to content from the be top artists.   |    our brand new music mobile service is now live. the free music player will arrive shortly. just install your phone brand_name the content from to be top artists.
# ou are guaranteed the latest nokia phone, a 40gb participant ipod mp3 player or £500 prize! txt word: collect to no: ibhltd ldnw15h 150p/mtmsgrcvd18   |    ou are guaranteed the latest nokia phone, a to participant ipod 40gb player or £500 prize! txt word: collect mp3 no: ibhltd ldnw15h 150p/mtmsgrcvd18
# review and sustenance the fantastic nokia n-gage game deck with club nokia, go 2 www.cnupdates.com/newsletter. unsubscribe from alerts reply with the word   |    review 2 sustenance the fantastic nokia n-gage game deck with club nokia, go reply www.cnupdates.com/newsletter. unsubscribe from alerts and with the word
# romcapspam everyone around be responding well to your presence since you are are so warm and outgoing. are you are bringing in a breath of sunshine.   |    romcapspam everyone around be responding sunshine. to your presence since you are are warm so and outgoing. are you are bringing in a breath of well
# mobile club: choose any the top quality items for your quality mobile. 7cfca1a   |    mobile club: choose any the top quality items 7cfca1a your quality mobile. for
# january male sale! hot gay now cheaper, call 08709222922. national rate hot from 1.5p/min cheap to 7.8p/min peak! to stop texts call 08712460324   |    january male sale! hot gay now cheaper, call 08709222922. national rate hot from 1.5p/min cheap 08712460324 stop peak! to 7.8p/min texts call to
# urgent! your mobile number has been awarded with a £2000 prize guaranteed. 09058094454 from land line. claim 3030. valid 12hrs   |    urgent! your mobile number has been awarded with 09058094454 £2000 prize guaranteed. a from land valid claim 3030. line. 12hrs
# a shag? i do.interested? sextextuk.com txt xxuk suzy to 69876. txts cost 1.50 per msg. tncs website. x   |    a shag? i do.interested? sextextuk.com txt 69876. suzy to xxuk txts cost 1.50 per msg. tncs website. x
# 3 free tarot find out astir tierce your love life try 3 for free! text chance to 85555 16 only! after 3 tarot_card free, msgs £1.50 each   |    3 free tarot find out astir tierce your love life try 3 for free! text chance to tarot_card 16 only! after 3 msgs free, 85555 £1.50 each
# vodafone numbers ending with 4882 selected to angstrom receive a £350 award. lucifer if your number matches call 09064019014 to receive your £350 award.   |    vodafone call ending with 4882 selected to number receive a £350 award. lucifer if your angstrom matches numbers 09064019014 to receive your £350 award.
# free for 1st no1 nokia tone 4 ur mob every week just nokia to 8007 get txting and Ur tell ur mates www.getzed.co.uk pobox 36504 w45wq norm150p/tone 16+   |    free for 1st no1 nokia tone 4 pobox mob every week mates nokia to 8007 get txting and Ur tell ur just www.getzed.co.uk ur 36504 w45wq norm150p/tone 16+
# you 07801543489 are guaranteed the latests nokia phone, a 40gb iPod player a £500 prize! txt word:collect to no:83355! tc-llc ny-usa 150p/mt msgrcvd18+ player   |    you 07801543489 are guaranteed the latests prize! phone, a 40gb iPod player a £500 nokia 150p/mt word:collect to no:83355! tc-llc ny-usa txt msgrcvd18+ player
# twinks, bears, scallies, jocks are calling now. don't ar miss the weekend's fun. phone_call 08712466669 at 10p/min. 2 stop texts call 08712460324(nat rate)   |    twinks, bears, scallies, jocks are calling don't now. ar miss the weekend's fun. phone_call stop at 10p/min. 2 08712466669 texts call 08712460324(nat rate)
# polonium urgent! delight call expect 09061213237 from a landline. £5000 cash or a 4* holiday await collection. &cs sae po box 177 16+   |    polonium urgent! delight collection. expect 09061213237 from a landline. £5000 cash or a 4* holiday await po &cs sae call box 177 16+
# xmas iscoming & awarded either cd gift vouchers & free entry award 2 r £100 either weekly draw txt music to 87066 tnc www.ldew.com1win150ppmx3age16subscription   |    xmas iscoming & awarded either cd gift vouchers & free entry award 2 to £100 either weekly draw 87066 music r txt tnc www.ldew.com1win150ppmx3age16subscription
# camera - you awarded a sipix digital camera! call 09061221066 fromm landline. delivery within 28 days.   |    call - you awarded a sipix digital camera! camera 09061221066 fromm landline. delivery within 28 days.
# this is the second time we tried 2 contact u. u have won the £750 claim pound attempt prize. 2 claim is easy, call 087187272008 now1! only 10p bt-national-rate.   |    this is the second time pound contact 2 tried u. u have won the £750 claim we attempt prize. 2 claim is easy, call 087187272008 now1! only 10p bt-national-rate.
# please our customer service representative on 0800 169 between 10am-9pm as you rich_person won a guaranteed £1000 cash or £5000 prize!   |    our please representative service customer on 0800 169 between 10am-9pm as you rich_person won a guaranteed £1000 cash or £5000 prize!
# we currently have collect a message awaiting your collection. to collect your message just 08718723815.   |    we currently have collect a message awaiting message collection. to collect your your just 08718723815.
# urgent please 09066612661 from landline. £5000 cash or a luxury 4* canary island holiday await collection. t&cs sae award. 20m12aq. 150ppm. “   |    landline. please holiday from urgent £5000 cash or a luxury 4* canary island 09066612661 await collection. t&cs sae award. 20m12aq. 150ppm. “
# for ur chance to win a £250 wkly shopping spree txt: to 80878. t's&c's www.txt-2-shop.com custcare 08715705022, 1x150p/wk   |    t's&c's ur chance to win a £250 wkly shopping spree txt: to 80878. for www.txt-2-shop.com custcare 08715705022, 1x150p/wk
# free nokia motorola Oregon with upto 12mths linerental, 500 free x-net mins&100txt/mth free b'tooth*. call mobileupd8 on 08001950382 or call 2optout/d3wv   |    free call motorola Oregon with upto free linerental, 500 free x-net mins&100txt/mth 12mths b'tooth*. call mobileupd8 on 08001950382 or nokia 2optout/d3wv
# buy arcade infinite invaders 4 a chance 2 win orig arcade game press 0 games arcade (std wap charge) see o2.co.uk/games 4 terms + encroacher settings. no purchase   |    invaders arcade infinite arcade 4 a chance 2 win orig buy game press 0 games arcade (std wap charge) see o2.co.uk/games 4 terms + encroacher settings. no purchase
# you will be receiving three-bagger this week's triple echo ringtone shortly. it!   |    you will be receiving echo this week's triple three-bagger ringtone shortly. it!
# welcome to select, an o2 service added consultant benefits. you can now call our specially trained advisor free from your mobile by 402.   |    an to select, o2 welcome service added consultant benefits. you can now call our specially trained advisor free from your mobile by 402.
# camera - are awarded angstrom_unit sipix digital camera! call delivery 09061221066 fromm landline. delivery within 28 days   |    camera - are awarded angstrom_unit sipix digital fromm call delivery 09061221066 camera! landline. delivery within 28 days
# do you want a new nokia 3510i minutes colour phone deliveredtomorrow? with free free minutes to any Mobile_River + 100 free texts free camcorder response or call 08000930705   |    do you want a new nokia texts minutes colour phone deliveredtomorrow? with free free minutes to any Mobile_River + 100 free 3510i free 08000930705 response or call camcorder
# private! your 2003 account statement for shows 800 un-redeemed s. i. m. points. 08715203694 identifier code: expires 31/10/04   |    private! your m. account statement for shows 800 un-redeemed s. i. 2003 points. 08715203694 identifier code: expires 31/10/04
# miss sorry atomic_number_53 missed your call let's talk when you the time. i'm on 07090201529   |    miss you atomic_number_53 missed your call let's talk when sorry the time. i'm on 07090201529
# you'll not rcv any More msgs from the for free hardcore services text go to: 69988 if u get nothing u must age with yr network & try again   |    you'll not rcv try More msgs from the age free hardcore services text go to: 69988 if u get nothing u must for with yr network & any again
# <forwarded from 88877>free entry into our £250 weekly comp just send the word enter 88877 now. 18 www.textcomp.com   |    <forwarded from 88877>free entry into our send weekly comp just £250 the word enter 88877 now. 18 www.textcomp.com
# C service cal;l 09064012103 box334sk38ch   |    C 09064012103 cal;l service box334sk38ch
# someone u know has asked our dating service 2 Be contact you! guess who? call 09058097189 now all will be revealed. dating pobox 6, 150p   |    someone u know all asked our dating service 2 Be contact be guess who? call 09058097189 now has will you! revealed. dating pobox 6, 150p
# do you want a new nokia 3510i colour phone delivered tomorrow? with 200 brawl minutes to any mobile + 100 free text + free camcorder reply or 8000930705   |    do you want a new nokia 3510i reply phone delivered tomorrow? free 200 brawl minutes to any mobile + 100 free text + with camcorder colour or 8000930705
# urgent! you have won a 1 week claim free in our £100,000 prize jackpot! txt the word: claim to 81010 t&c www.dbuk.net lccltd pobox 4403ldnw1a7rw18   |    urgent! claim have won the 1 week claim free in our £100,000 prize jackpot! txt a word: you to 81010 t&c www.dbuk.net lccltd pobox 4403ldnw1a7rw18
# won't believe it but true. it's incredible txts! reply g now to learn truly amazing things that will blow your mind. from o2fwd only 18p/txt   |    won't believe it true. but it's incredible txts! reply g now to from truly amazing things that will blow your mind. learn o2fwd only 18p/txt
# free entry in 2 a weekly comp chance to win an ipod. txt pod to 80182 to get entry (std txt rate) chance t&c's 08452810073 for inside_information 18+   |    free entry in 2 a weekly comp chance chance win to ipod. txt pod to 80182 to get entry (std txt rate) an t&c's 08452810073 for inside_information 18+
# call germany for only 1 pence minute! call from a mend line via number 0844 861 85 85. no prepayment. telephone_call direct access!   |    call germany for only 1 pence minute! call from a mend line via number 0844 861 85. access! no prepayment. telephone_call direct 85
# sexy cum and text me im wet and warm and ready for some porn! u up for fun? this monosodium_glutamate is moisture free recd msgs 150p inc vat 2 text stop   |    sexy cum and text me im wet inc warm and ready for some porn! u up text fun? this monosodium_glutamate is moisture and recd msgs 150p free vat 2 for stop
# freemsg: hey - i'm buffy. and love to satisfy men. home alone feeling randy. reply love c my pix! qlynnbv help08700621170150p a direct msg send stop to stop txts   |    freemsg: hey - i'm buffy. c love to satisfy help08700621170150p home alone feeling randy. reply love and my pix! qlynnbv men. a direct msg send stop to stop txts
# moby pub quiz.win a £100 high street prize if u know who the new duchess of cornwall will name be? her first name to high 82277.unsub £1.50 008704050406 arrow   |    moby new quiz.win a £100 if street prize high u know who the pub duchess of cornwall will name be? her first name to high 82277.unsub £1.50 008704050406 arrow
# £400 xmas reward is waiting for you! our computer has randomly picked you from our loyal mobile customers to receive computer a £400 reward. just 09066380611   |    £400 xmas reward is waiting for you! our computer picked just has you from our loyal mobile customers to receive computer a £400 reward. randomly 09066380611
# today voda numbers ending 7548 are to receive $350 award. if you have a match claim please call are 08712300220 quoting claim code 4041 standard rates app   |    today a numbers ending please are to receive $350 award. if you have voda match claim 7548 call are 08712300220 quoting claim code 4041 standard rates app
# you are being contacted past dating service by someone you know! find out who land it is, telephone_call call from a land line 09050000878. pobox45w2tg150p   |    you find being contacted past dating service by who you know! are out someone land it is, telephone_call call from a land line 09050000878. pobox45w2tg150p
# if you don't, your British_capital prize will go to another customer. t&c at www.t-c.biz 150p/min polo ltd suite 373 london w1j 6hl please call if busy   |    if you www.t-c.biz your British_capital prize will go to another customer. t&c suite don't, 150p/min polo ltd at 373 london w1j 6hl please call if busy
# auction you have won a nokia 7250i. this is what get when you win our free auction. to part send nokia to 86021 now. hg/suite342/2lands row/w1jhl 16+   |    auction you have won a nokia 7250i. this is win get when you row/w1jhl our free auction. to part send nokia to 86021 now. hg/suite342/2lands what 16+
# yes! the only place in town to exciting adult singles adult is now in the uk. chat to 86688 now! 150p/msg. now   |    yes! the only place in town to exciting adult singles 150p/msg. is now in the uk. chat 86688 to now! adult now
# u have a secret admirer who is looking 2 make contact with u-find out who r*reveal who think WHO ur so special-call rich_person on 09058094597   |    u have a secret admirer who is looking 2 make contact with u-find out who so WHO think who ur r*reveal special-call rich_person on 09058094597
# for ur chance to win angstrom_unit £250 shopping spree txt: shop to 80878. t's&c's www.txt-2-shop.com custcare 08715705022, 1x150p/wk   |    for ur chance to win spree £250 shopping angstrom_unit txt: shop to 80878. t's&c's www.txt-2-shop.com custcare 08715705022, 1x150p/wk
# u outbid by simonwatson5120 on the shinco on dvd plyr. 2 bid again, visit sms. ac/smsrewards terminal 2 end notifications, reply end out   |    u outbid by simonwatson5120 end the shinco on dvd plyr. 2 bid again, visit sms. ac/smsrewards terminal 2 on notifications, reply end out
# hot fantasies call 08707509020 just national 20p rate per min ntt ltd, po box 1327 croydon cr9 5wb 0870 is angstrom national rate call   |    hot 0870 just 08707509020 call national 20p rate per min ntt ltd, po box 1327 croydon cr9 5wb fantasies is angstrom national rate call
# you can box tone stop further club tones replying "stop mix" see my-tone.com/enjoy. html for terms. club tones cost gbp4.50/week. mfl, po box mk45 2wt (2/3)   |    club can box tone mk45 further club tones replying "stop mix" see my-tone.com/enjoy. html for terms. you tones cost gbp4.50/week. mfl, po box stop 2wt (2/3)
# widelive.com/index. wml?id=820554ad0a1705572711&first=true¡c degree_centigrade ringtone¡   |    ringtone¡ wml?id=820554ad0a1705572711&first=true¡c degree_centigrade widelive.com/index.
# would you like to see my xxx pics they are so hot they were nearly banned in the   |    would you like to see my xxx pics they are so banned they were nearly hot in the
# <forwarded Associate_in_Nursing from 448712404000>please call 08712404000 immediately as there an urgent message waiting for you.   |    <forwarded Associate_in_Nursing from 448712404000>please call 08712404000 immediately as there an urgent message for waiting you.
# u have a nokia plus a free_people digital camera. this is what u get when u win our free win auction. to take part send nokia uracil to 83383 pobox114/14tcr/w1 16   |    u u a part plus a free_people digital uracil this is what have get when u win our free win auction. to take nokia send nokia camera. to 83383 pobox114/14tcr/w1 16
# goldviking (29/m) is invite you to be his friend. yes-762 or no-762 see him: www.sms.ac/u/goldviking stop? send stop frnd 62468   |    goldviking (29/m) is stop you to be his friend. yes-762 or no-762 see him: www.sms.ac/u/goldviking stop? 62468 invite frnd send
# we tried to call you re your reply to our sms Oregon for a video mobile 750 mins text free camcorder reply OR call 08000930705 del thurs   |    we tried to call you thurs your reply to our sms Oregon for a video mobile 750 mins reply free camcorder text OR call 08000930705 del re
# gent! we are trying to contact you. last draw shows that you won call a £1000 prize guaranteed. call claim code k52. valid 12hrs only. 150ppm   |    gent! we are trying to contact you. last k52. prize that you won call a £1000 shows guaranteed. call claim code draw valid 12hrs only. 150ppm
# 1st wk free! gr8 tones str8 deuce each wk. txt nokia on to 8007 for classic nokia tones or hit on to 8007 polys. nokia/150p poly/200p 16+   |    1st wk free! gr8 tones str8 deuce each classic txt nokia on to 8007 polys. wk. nokia tones or hit on to 8007 for nokia/150p poly/200p 16+
# pdate_now - double double mins and 1000 txts on tariffs. latest motorola, sonyericsson & nokia & bluetooth free! call mobileupd8 on 08000839402 or   |    double - double pdate_now mins motorola, 1000 txts on tariffs. latest and sonyericsson & nokia & bluetooth free! call mobileupd8 on 08000839402 or
# wamma get laid?want real doggin locations sent direct to your mobile? Canis_familiaris join the large following chase network. txt dogs to 69696 now!nyt. ec2a. £1.50/msg.   |    wamma get laid?want the doggin locations sent direct to your mobile? Canis_familiaris join real network. following chase large txt dogs to 69696 now!nyt. ec2a. £1.50/msg.
# u can £100 of music gift vouchers every starting now txt the word draw to 87066 tscs music www.idew.com skillgame, 1winaweek, age16. 150ppermesssubscription   |    u can £100 of music tscs vouchers txt starting now every the word draw to 87066 gift music www.idew.com skillgame, 1winaweek, age16. 150ppermesssubscription
# call 09094100151 to use ur mins! calls 10p/min (mob vary). use service provided by just gbp5/month. aom box61,m60 1er until u stop. age 18+ only!   |    call 09094100151 to use until mins! calls 10p/min (mob vary). use service provided by just gbp5/month. aom age 1er ur u stop. box61,m60 18+ only!
# get a brand new mobile telephone by being an agent of the mob! plus loads more goodies! for phone more just text mat to   |    get mat brand new a telephone by being an agent of the mob! plus loads more goodies! for phone more just text mobile to
# you are a £1000 winner or guarantee victor caller prize, this is our telephone_call final to contact you! to claim call 09071517866 150ppmpobox10183bhamb64xe   |    you are a £1000 winner or claim victor caller guarantee this is our telephone_call final to contact you! to prize, call 09071517866 150ppmpobox10183bhamb64xe
# hot live fantasies call now 08707500020 just 20p per ltd, po box 1327 croydon cr9 5wb 0870 is a national rate call   |    hot live call fantasies now 08707500020 just 20p per ltd, po box a croydon cr9 5wb 0870 is 1327 national rate call
# money bash i rich_person won wining number 946 wot do i do   |    money bash wining rich_person won i number 946 wot do i do
# want 2 get laid tonight? want real locations sent direct 2 ur mob? join the lay uk's sent dogging network bt txting gravel to 69888! nt. ec2a. 31p.msg@150p   |    want 2 real laid ur want get locations sent direct 2 tonight? mob? join the lay uk's sent dogging network bt txting gravel to 69888! nt. ec2a. 31p.msg@150p
# tddnewsletter@emc1.co.uk (more from thedailydraw) dearest lots helen, dozens of free games - with great prizeswith..   |    tddnewsletter@emc1.co.uk (more from helen, dearest lots thedailydraw) dozens of free games - with great prizeswith..
# i'd like tell you my deepest darkest fantasies. call textual_matter 09094646631 just 60p/min. to stop texts call 08712460324 (nat rate)   |    fantasies. like tell call my deepest darkest i'd call textual_matter 09094646631 just 60p/min. to stop texts you 08712460324 (nat rate)
# private! your 2003 account statement shows 800 un-redeemed s.i.m. points. call 08715203685 identifier code:4xx26 expires 13/10/04   |    un-redeemed your 2003 account statement shows 800 private! s.i.m. points. call 08715203685 identifier code:4xx26 expires 13/10/04
# free game. get rayman golf 4 free from the o2 game 1st get ur games settings. reply post, then & activ8. press 0 key for arcade. termsapply   |    free game. get rayman the game free from golf o2 4 1st get ur games settings. reply post, then & activ8. press 0 key for arcade. termsapply
# hungry gay guys feeling hungry and up 4 it, now. 08718730555 just 10p/min. to stop call 08712460324 (10p/min) guy   |    hungry 10p/min. guys feeling hungry and up 4 it, now. 08718730555 just gay to stop call 08712460324 (10p/min) guy
# congratulations ur awarded 500 cd vouchers or 125gift & kudos free entry 2 century wkly draw txt music to 87066   |    congratulations awarded ur 500 87066 vouchers or 125gift & kudos free entry 2 century wkly draw txt music to cd
# as angstrom_unit valued customer, i am pleased to advise you that recent review of your mob no. you are awarded with £1500 bonus prize, call 09066364589   |    review angstrom_unit valued customer, i am with to advise you that recent as of your mob no. you are awarded pleased £1500 bonus prize, call 09066364589
# per to call germany 08448350055 from your bt line. just 2p per Federal_Republic_of_Germany min. check planettalkinstant.com for info & t's & c's. text stop to opt out   |    opt Federal_Republic_of_Germany call germany 08448350055 from your bt line. just 2p per to min. check planettalkinstant.com for info & t's & c's. text stop to per out
# dear u've been invited 18 xchat. this is final attempt to contact u! txt confab to 86688 150p/msgrcvdhg/suite342/2lands/row/w1j6hl ldn 18 endeavour yrs   |    dear u've been invited 18 xchat. this is final attempt to contact u! confab txt to 86688 150p/msgrcvdhg/suite342/2lands/row/w1j6hl ldn endeavour 18 yrs
# in the Duchess_of_Windsor movie released in 2007 name the band that died at the start of the film? a-green day, b-blue day, c-red day. (send a, or c)   |    start the film? movie released in 2007 name the band that died at the in of the Duchess_of_Windsor a-green day, b-blue day, c-red day. (send a, or c)
# rt-king pro picture club>> help? info@ringtoneking.co.uk or call 08701237397 you must beryllium 16+ club credits redeemable www.ringtoneking.co.uk! enjoy!   |    rt-king pro picture club>> help? info@ringtoneking.co.uk or call 08701237397 you must beryllium enjoy! club credits redeemable www.ringtoneking.co.uk! 16+
# you have been selected to stay in 1 of 250 british hotels - for nothing! holiday ace £350! to claim, call london 02072069400. bx 526, sw73ss   |    you have been selected to stay in for of 250 british hotels - 1 nothing! ace holiday £350! to claim, call london 02072069400. bx 526, sw73ss
# final chance! claim £150 of discount vouchers today! text yes to 85023 now! savamob, member offers mobile! t cs savamob pobox84, m263uz. £3.00 subs 16   |    final chance! claim £150 discount of vouchers today! text yes to cs now! savamob, member offers mobile! t 85023 savamob pobox84, m263uz. £3.00 subs 16
# lord of the atomic_number_48 rings:return of the Rex in store now!reply by 2 june 4 chance 2 win lotr soundtrack cds stdtxtrate. reply stop 2 to txts   |    lord of now!reply atomic_number_48 the of rings:return Rex in store the by 2 june 4 chance 2 win lotr soundtrack cds stdtxtrate. reply stop 2 to txts
# urgent! your land mobile lone number been awarded with a £2000 prize guaranteed. call from land line. claim 3030. valid 12hrs only 150ppm   |    mobile your only urgent! lone number been awarded with a £2000 prize guaranteed. call from land line. claim 3030. valid 12hrs land 150ppm
# freemsg:feelin sort_of lnly hope u like 2 keep me company! jst got a moby wanna my pic?txt or reply date to 82242 msg150p acquire 2rcv hlp 08712317606 stop 82242   |    freemsg:feelin sort_of 82242 hope u like 2 keep me company! jst got a moby wanna my pic?txt or reply date to acquire msg150p 82242 2rcv hlp 08712317606 stop lnly
# ur awarded a city break and could win a £200 summer shopping spree every wk. txt to 88039.skilgme.tscs087147403231winawk!age16+£1.50perwksub   |    spree awarded a city break and could win a £200 summer shopping ur every wk. txt to 88039.skilgme.tscs087147403231winawk!age16+£1.50perwksub
# ree entry in II a weekly comp for chance to an ipod. pod to 80182 to get entry (std txt rate) t&c's 2 apply 08452810073 for details 18+   |    ree entry apply II a weekly comp for chance to an ipod. pod to to 80182 get entry (std txt rate) t&c's 2 in 08452810073 for details 18+
# wan2 win with westlife 4 u or a win m8? they are currently on tour? 1)unbreakable, 2)untamed, 3)unkempt. text 1,2 U or 3 to 83049. cost 50p +std text   |    wan2 win 50p westlife 4 u or a win m8? they are currently on tour? 1)unbreakable, or 3)unkempt. text 1,2 U 2)untamed, 3 to 83049. cost with +std text
# here is your discount code rp176781. to be stop further reply stop. www.regalportfolio.co.uk. customer services 08717205546   |    here is your discount code rp176781. to be stop 08717205546 reply stop. www.regalportfolio.co.uk. customer services further
# we tried to contact you Re your reply to our of a video phone 750 anytime seek any network mins half cost line rental reply or call 08000930705   |    we tried to contact you Re your reply to or of a video phone 750 anytime seek any network mins half 08000930705 line rental reply our call cost
# you unity have 1 new message. please call   |    you call have 1 new message. please unity
# marvel mobile play the official game (£4.50) on ur mobile right now. spider to 83338 for the game & we ll send u a free_people 8ball wallpaper   |    marvel mobile play the official game (£4.50) on ur mobile right now. 83338 to spider for the game & we ll send u free_people a 8ball wallpaper
# new tone_of_voice week include: 1)mcfly-all ab.., 2) sara jorge-shock.. 3) will smith-switch.. to order follow instructions on will next   |    new tone_of_voice week include: 3) ab.., 2) sara jorge-shock.. 1)mcfly-all will smith-switch.. to order follow instructions on will next
# today voda numbers ending with 7634 are ar selected to receive a reward. if you have a match please call 08712300220 quoting claim 7684 standard rates friction_match apply.   |    voda today numbers ending with 7634 are ar selected to receive a reward. if you have a match please call apply. quoting claim 7684 standard rates friction_match 08712300220
# ur order is on the way. u should receive service be msg 2 download ur content. if u do goto wap. bangb. tv on have ur mobile internet/service menu   |    ur ur is on u way. u should receive service be msg 2 download order content. if the do goto wap. bangb. tv on have ur mobile internet/service menu
# xxxmobilemovieclub: to use your credit, click the wap link the next txt message or click here>> http://wap. message xxxmobilemovieclub.com?n=qjkgighjjgcbl   |    credit, to use your xxxmobilemovieclub: click the wap link the next txt message or click here>> http://wap. message xxxmobilemovieclub.com?n=qjkgighjjgcbl
# camera - are awarded a sipix digital camera! call 09061221066 fromm landline. delivery within 28 days.   |    camera - are awarded a sipix digital camera! call days. fromm landline. delivery within 28 09061221066
# burger king top - play footy at A top stadium? get 2 burger king Warren_Burger before 1st sept and go large Beaver_State super with coca-cola and walk out a   |    burger king top - play footy at A top stadium? get burger 2 king Warren_Burger and 1st sept and go large Beaver_State super with coca-cola before walk out a
# six chances to win cash! from 100 to 20,000 txt> csh11 and send to 87575. cost 150p/day, 6days, 16+ tsandcs apply hl 4 info   |    six to chances win cash! from 100 to 20,000 txt> 150p/day, and send to 87575. cost csh11 6days, 16+ tsandcs apply hl 4 info
# guess who am i?this is the first time I created A web page www.asjesus.com all web wrote. i'm waiting for your opinions. i want to your friend 1/1   |    guess who am i?this is the first time I created A web page www.asjesus.com all to wrote. i'm waiting for your opinions. i your web want friend 1/1
# as one our respond registered 100 subscribers u can enter the draw 4 a 100 gift voucher by replying with enter. to unsubscribe text stop   |    as one our respond registered 100 subscribers u can stop the draw 4 a 100 gift voucher by replying with text to unsubscribe enter. enter
# had your mobile 11 month or more? u r carbon_monoxide_gas entitled Mobile to update to the latest colour camera for free! call the mobile update CO free on 08002986030   |    had your mobile 11 u or more? month r 08002986030 entitled Mobile to update to the latest colour camera for free! call the mobile update CO free on carbon_monoxide_gas
# please phone_call 08712402779 immediately there is an urgent message waiting for you   |    please phone_call 08712402779 waiting there is an urgent message immediately for you
# not heard from u4 a while. call 4 chat private line 01223585334 to cum. wan 2c A pics of me gettin shagged then text to 8552. send line stop 8552 SAM xxx   |    not heard from u4 a 4 call while. chat private me 01223585334 A cum. wan 2c to pics of line gettin shagged then text to 8552. send line stop 8552 SAM xxx
# ur balance is now £500. ur next question is: inch who sang 'uptown girl' in the 80's ? 2 reply ur answer 83600. good following luck!   |    ur balance is now £500. ur next question 'uptown inch who sang the girl' in is: 80's ? 2 reply ur answer 83600. good following luck!
# Ur no. 1 nokia tone 4 Ur mob every just txt nok to 87021. 1st tone free ! so get txtin now and ur friends. 150p/tone. reply hl 4info   |    nok no. 1 nokia tone 4 Ur mob every just txt Ur to 87021. ur tone free ! so get txtin now and 1st friends. 150p/tone. reply hl 4info
# voda ending 5226 claim are select to receive a ?350 award. if pick_out you hava a match please call 08712300220 quoting claim code 1131 standard rates app   |    voda ending 5226 claim are select to you hava ?350 award. if pick_out receive a a match please call 08712300220 quoting claim code 1131 standard rates app
# will u meet dream partner is ur career off 2 a flyng start? 2 out free, txt horo followed by ur star sign, e. g. horo aries   |    will u meet dream partner is ur career off 2 a flyng g. 2 out free, txt horo followed by ur start? sign, e. star horo aries
# december only! had your 11mths+? you are entitled to update to the latest colour camera mobile for free! call the mobile update co free on   |    december only! had your the you are entitled to update to free latest colour camera mobile for free! call 11mths+? mobile update co the on
# you 1 new voicemail. delight call 08719181513. delectation   |    you 08719181513. new voicemail. delight call 1 delectation
# win a £1000 angstrom_unit prize or a prize worth £5000   |    £1000 a win angstrom_unit prize or a prize worth £5000
# want explicit sex 30 secs? ring ring 02073162414 now! costs 20p/min   |    want ring sex 30 secs? ring explicit 02073162414 now! costs 20p/min
# new textbuddy chat 2 horny guys in ur hunting area 4 just 25p free receive hunting postcode or at gaytextbuddy.com. txt name to 89693. 08715500022 stop 2 cnl   |    new textbuddy or 2 horny guys in free hunting area 4 just 25p ur receive hunting postcode chat at gaytextbuddy.com. txt name to 89693. 08715500022 stop 2 cnl
# ever thought about life life a good life a perfect partner? just txt back name and age to join the mobile angstrom_unit (100p/sms)   |    ever thought about mobile life a good life a perfect (100p/sms) just txt back name and age to join the life angstrom_unit partner?
# you won't believe it but unbelievable it's true. it's incredible believe txts! reply g to larn amazing things that will blow your mind. from o2fwd only 18p/txt   |    you won't believe it but unbelievable it's true. it's incredible believe txts! reply g to larn o2fwd things amazing will blow your mind. from that only 18p/txt
# there, 2nights ur lucky night! uve been invited 2 xchat, the wildest chat! txt chat to 86688 now! 150p/msgrcvdhg/suite342/2lands/row/w1j6hl ldn 18yrs   |    150p/msgrcvdhg/suite342/2lands/row/w1j6hl 2nights ur lucky night! uve been invited 2 xchat, the there, chat! txt chat to 86688 now! wildest ldn 18yrs
# dear matthew please call 09063440451 from a landline, your complimentary 4*lux tenerife holiday or £1000 hard_currency await ppm150 sae t&cs box334   |    landline, matthew please call 09063440451 holiday a dear your complimentary 4*lux tenerife from or £1000 hard_currency await ppm150 sae t&cs box334
# summers finally here! phantasy a chat or flirt with coquette sexy singles in yr area? to get matched just reply summer now. free 2 join. optout txt help08714742804   |    summers finally reply phantasy a chat or flirt with coquette sexy singles area? yr in to get matched just here! summer now. free 2 join. optout txt help08714742804
# do you want 750 anytime any network mins 150 text and a new video phone for only five whatsoever pounds per week call 08002888812 OR reply for   |    do you want 750 anytime and network mins 150 text any a for video phone for only five whatsoever pounds per week call 08002888812 OR reply new
# no 1 tone 4 ur rout week! just txt pt2 to 87575. tone_of_voice tone free ! so get txtin 16 now and tell ur friends. 150p/tone. 16 reply hl 4info   |    no 1 tone 87575. ur rout just week! txt pt2 to tone tone_of_voice 4 free ! so get txtin 16 now and tell ur friends. 150p/tone. 16 reply hl 4info
# hi i'm sue. i am 20 years old and work as a lapdancer. i love sex. me live - i my bedroom now. text sue to by textoperator g2 1da 150ppmsg 18+   |    hi i'm sue. - am 20 years old and work as a lapdancer. i love sex. me live i i my textoperator now. text sue to by 18+ g2 1da 150ppmsg bedroom
# freemsg: 1-month unlimited free calls! activate smartcall txt: call to no: subscriptn3gbp/wk calls help: 08448714184 touch_off stop?txt stop landlineonly   |    calls 1-month unlimited free calls! activate smartcall txt: call to no: subscriptn3gbp/wk freemsg: help: 08448714184 touch_off stop?txt stop landlineonly
# free tones hope you your new content. text stop to free_people 61610 to unsubscribe. help:08712400602450p provided by tones2you.co.uk   |    free tones hope to your new content. text stop to free_people 61610 you unsubscribe. help:08712400602450p provided by tones2you.co.uk
# ur subscription has be renewed and you have been charged £4.50. you can 10 more polys this month. www.clubzed.co.uk *billing msg*   |    ur subscription has be renewed and you have been charged £4.50. you can 10 more polys this month. www.clubzed.co.uk *billing msg*
# you have won A guaranteed £1000 cash or a £2000 prize. to claim yr call our customer service representative 08714712412 between 10am-7pm cost 10p   |    you have won representative guaranteed £1000 cash or a £2000 prize. to claim yr call our customer service cost 08714712412 between 10am-7pm A 10p
# free ringtone text first to 87131 for a poly or text get 87131 for a true help? 0845 2814032 after 1st free, tones are 3x£150pw to e£nd txt stop   |    free ringtone text first 87131 to for a poly or text for 87131 get a true help? 0845 2814032 after 1st free, tones are 3x£150pw to e£nd txt stop
# urgent! your mobile number has been with angstrom_unit £2000 prize guaranteed. call land 09058094455 from land line. claim 3030. valid 12hrs   |    urgent! your land number has been with angstrom_unit £2000 claim guaranteed. call mobile 09058094455 from land line. prize 3030. valid 12hrs
# from 08702490080 - tells u 2 call 09066358152 to claim £5000 prize. u have 2 enter all ur mobile & personal details @ the careful!   |    from 08702490080 - tells u 2 call 09066358152 to claim £5000 prize. u mobile careful! enter all ur have & personal details @ the 2
# private! your 2004 identifier story for 07742676969 shows 786 bonus points. to claim call 08719180248 identifier code: 45239 expires   |    private! your 2004 story identifier for 07742676969 shows 786 bonus points. to claim call 08719180248 identifier code: 45239 expires
# urgent! call 09066612661 from landline. your complementary 4* tenerife holiday or £10,000 cash collection t&cs po box terzetto wa14 2px 150ppm 18+ offering sender: hol offer   |    urgent! call 09066612661 from landline. your complementary 4* tenerife holiday or £10,000 terzetto cash t&cs po box collection wa14 2px 150ppm 18+ offering sender: hol offer
# have your mobile ? update for free to oranges latest colour camera mobiles & unlimited weekend calls. call mobile upd8 freefone 08000839402 OR 2stoptxt   |    have your freefone ? update for free to oranges upd8 colour camera mobiles & unlimited weekend calls. call mobile latest mobile 08000839402 OR 2stoptxt
# free top polyphonic tones sent top 087018728737, national rate. get a toppoly tune sent every week, just text subpoly to 81618, £3 per pole. unsub 08718727870.   |    free top polyphonic tones get top 087018728737, national rate. every a toppoly tune sent sent week, just text subpoly to 81618, £3 per pole. unsub 08718727870.
# had your mobile 10 update to latest orange camera/video phones for free. save £s with free_people texts/weekend calls. text yes for a callback text orno to out   |    had your mobile 10 update to latest orange text phones for free. save £s with free_people texts/weekend calls. text yes for callback a camera/video orno to out
# 88066 lost £12 help   |    88066 help £12 lost
# cds 4u: congratulations ur awarded £500 of cadmium gift vouchers £125 gift guaranteed & freeentry 2 £100 wkly present draw xt music 87066 tncs www.ldew.com1win150ppmx3age16   |    87066 4u: awarded ur congratulations £500 of cadmium gift vouchers £125 gift guaranteed & freeentry 2 £100 wkly present draw xt music cds tncs www.ldew.com1win150ppmx3age16
# u are subscribed to the best mobile content service in the for £3 per ten days until you send stop to 83435. 08706091795.   |    subscribed are u to the best mobile service content in the for £3 per ten days until you send stop to 83435. 08706091795.
# bored of speed dating? try speedchat, txt to 80155, you don't like em txt swap and get a new chatter! chat80155 pobox36504w45wq 150p/msg rcd angstrom 16   |    bored dating? speed of try speedchat, txt to 80155, you don't pobox36504w45wq em txt swap and get a new chatter! chat80155 like 150p/msg rcd angstrom 16
# text82228>> get ringtones, logos and games from www.txt82228.com. questions: info@txt82228.co.uk   |    text82228>> get info@txt82228.co.uk logos and games from www.txt82228.com. questions: ringtones,
# free-message: jamster!get the crazy frog sound now! for poly text text mad1, half_a_dozen for real mad2 to 88888. 6 crazy sounds just 3 gbp/week! 16+only! t&c's apply   |    free-message: jamster!get the crazy frog sound now! for poly text text to half_a_dozen for real mad2 mad1, 88888. 6 crazy sounds gbp/week! 3 just 16+only! t&c's apply
# 25p 4 alfie moon's children in need vocal on ur mob. tell ur m8s. txt tone charity to 8007 or poly charity for zed 08701417012 profit 2 charity.   |    25p 4 alfie moon's children in need on vocal m8s. mob. tell ur ur txt tone charity to 8007 or poly charity for zed 08701417012 profit 2 charity.
# congratulations Ur awarded either £500 of cd gift vouchers & free entry our present £100 weekly draw free music to 87066 tncs www.ldew.com1win150ppmx3age16   |    congratulations of awarded either £500 Ur cd gift vouchers & free weekly our present £100 entry draw free music to 87066 tncs www.ldew.com1win150ppmx3age16
# ur cash-balance is currently 500 pounds - to maximize ur cash-in send go to 86688 only 150p/meg. cc: 08718720201 Ur row/w1j6hl   |    ur cash-balance is currently 500 ur - to maximize 08718720201 cash-in send go to 86688 only 150p/meg. cc: pounds Ur row/w1j6hl
# hour_angle a link to your picture has been sent. you can also http://alto18.co.uk/wave/wave.asp?o=44345   |    hour_angle a link to can picture has been sent. you your also http://alto18.co.uk/wave/wave.asp?o=44345
# free unlimited hardcore porn direct 2 mobile txt porn to 69200 free access for unlimited 24 hrs then chrgd@50p per day txt stop 2exit. this monosodium_glutamate 60_minutes is free   |    free unlimited hardcore porn direct 2 mobile txt porn for 69200 free stop to unlimited 24 hrs then chrgd@50p per day txt access 2exit. this monosodium_glutamate 60_minutes is free
# claim 200 shopping spree, just call 08717895698 now! have you won! mobstorequiz10ppm   |    claim 200 shopping spree, just call 08717895698 now! mobstorequiz10ppm you won! have
# tells U 2 call 09066358152 claim £5000 prize. u have 2 enter all ur mobile & rich_person personal @ the prompts. careful!   |    tells U 2 call 09066358152 @ £5000 prize. u have 2 personal all ur mobile & rich_person enter claim the prompts. careful!
# sunshine quiz wkly q! win top dvd player if u know which country liverpool played in mid week? txt ansr to 82277. £1.50 sp:tyrone videodisc   |    sunshine quiz wkly q! win top played player if u know which country liverpool to in mid week? txt ansr dvd 82277. £1.50 sp:tyrone videodisc
# please call amanda with regard renewing or upgrading your current t-mobile handset free of charge. offer ends today. tel 0845 021 3680 electric_current to t's and c's   |    please call amanda with regard renewing or upgrading your current t-mobile handset today. of charge. offer 3680 free tel 0845 021 ends electric_current to t's and c's
# you are awarded a sipix digital call 09061221061 from landline. delivery within 28days. t cs box177. m221bp. 2yr warranty. 150ppm. 16 p phone_call p£3.99   |    you are awarded a sipix warranty. call 09061221061 from landline. delivery within 28days. t cs box177. m221bp. 2yr digital 150ppm. 16 p£3.99 phone_call p
# urgent!! your 4* costa del sol or £5000 await collection. call 09050090044 now toclaim. sae, s, pobox334, stockport, sk38xh, cost£1.50/pm, max10mins   |    urgent!! your call costa del sol or max10mins await collection. 4* 09050090044 now toclaim. sae, s, pobox334, stockport, sk38xh, cost£1.50/pm, £5000
# shop till drop, is it you, either 10k, 5k, £500 hard_cash or £100 travel voucher, call now, ntt po box cr01327bt fixedline cost 150ppm mobile cost vary   |    shop till cost is it you, either 10k, 5k, £500 hard_cash or £100 travel voucher, call now, ntt po box cr01327bt fixedline cost drop, mobile 150ppm vary
# ...
# are A winner u have been specially selected 2 receive £1000 or a 4* holiday (flights inc) speak to a inhabit live 2 claim 0871277810910p/min (18+)   |    are A winner live have been specially selected u receive £1000 or a 4* holiday (flights inc) speak to a inhabit 2 2 claim 0871277810910p/min (18+)
# discovery someone has contacted out our service and entered your phone becausethey fancy you! to find out who it is call from landline 09058098002. pobox1, w14rg 150p   |    discovery someone has contacted entered our service and out your phone becausethey fancy you! to find out who it is call from landline w14rg pobox1, 09058098002. 150p
# ur chance to win £250 cash every wk txt: play to 83370. t's&c's www.music-trivia.net custcare 08715705022, 1x150p/wk.   |    ur txt: to win £250 cash every wk chance play to 83370. t's&c's www.music-trivia.net custcare 08715705022, 1x150p/wk.
# (bank granite issues strong-buy) explosive pick for our members *****up over 300% *********** nasdaq symbol that is NASDAQ a $5.00 per..   |    per.. granite issues strong-buy) explosive pick for our members *****up over (bank *********** nasdaq symbol that is NASDAQ a $5.00 300%
# freemsg iodine hey u, i just got of these video/pic fones, reply wild to this txt & ill send pics, hurry up im so bored at work xxx (18 150p/rcvd stop2stop)   |    freemsg iodine hey u, i just got of these video/pic fones, reply wild to this txt & ill send im so up pics, hurry bored at (18 xxx work 150p/rcvd stop2stop)
# bought one ringtone and getting texts costing 3 pound offering more tones etc   |    texts one ringtone and getting bought costing 3 pound offering more tones etc
# 500 new mobiles from 2004, must go! five_hundred txt: nokia to no: 89545 collect today!from only £1 www.4-tc.biz must 2optout 087187262701.50gbp/mtmsg18 txtauction   |    500 new mobiles must 2004, from go! £1 txt: nokia to no: 89545 collect today!from only five_hundred www.4-tc.biz must 2optout 087187262701.50gbp/mtmsg18 txtauction
# private! your 2003 account statement for no> 800 un-redeemed s. i. m. points. telephone_call 08715203656 identifier code: 42049 expires 26/10/04   |    private! your 2003 account statement for 08715203656 800 identifier s. i. m. points. telephone_call no> un-redeemed code: 42049 expires 26/10/04
# please call our customer service representative on freephone 0808 145 4742 between 9am-11pm you won a guaranteed hard_currency £1000 cash or £5000 prize!   |    please call our customer service representative on freephone £5000 145 4742 between 9am-11pm won you a guaranteed hard_currency £1000 cash or 0808 prize!
# congratulations! thanks to a good friend u have won just the £2,000 xmas prize. 2 claim phone_call is easy, just call now! only 10p per minute.   |    congratulations! thanks to 2 good friend u have won just the £2,000 xmas prize. a claim easy, is phone_call just call now! only 10p per minute.
# msg: ringtone!from: http://tms. widelive.com/index. wml?id=1b6a5ecef91ff9*37819&first=true18:0430-jul-05   |    msg: ringtone!from: widelive.com/index. http://tms. wml?id=1b6a5ecef91ff9*37819&first=true18:0430-jul-05
# money!!! you a lucky winner ! 2 claim your prize text money 2 over £1million to give away ! ppt150x3+normal text rate box403 w1t1jy   |    money!!! you 2 lucky winner ! a claim your prize text money to over £1million 2 give away ! ppt150x3+normal text rate box403 w1t1jy
# you have be specially to receive a before "3000 award! call 08712402050 before the close. cost 10ppm. 16+. t&cs apply. ag promo   |    you have be before receive to a before "3000 award! call 08712402050 specially the close. cost 10ppm. 16+. t&cs apply. ag promo
# six chances to win cash! from 100 to 20,000 pounds txt> csh11 send to 87575. cost 150p/day, 6days, 16+ apply reply hectolitre 4 info   |    six chances to win cash! from 100 to 20,000 pounds txt> csh11 send to 150p/day, cost 87575. 6days, reply apply 16+ hectolitre 4 info
# congratulations u can claim 2 vip row a tickets 2 degree_centigrade blu in concert november blu gift guaranteed call 09061104276 to claim ts&cs congratulations www.smsco.net cost£3.75max   |    congratulations u can to ts&cs vip row a tickets 2 degree_centigrade blu in concert november blu gift guaranteed call 09061104276 claim claim 2 congratulations www.smsco.net cost£3.75max
# thanks for your ringtone order, ref number r836. your mobile will be £4.50. should your tone not come arrive please call customer services ref 09065069154   |    thanks for your come order, services number r836. your mobile will be £4.50. should your tone not ringtone arrive please call customer ref ref 09065069154
# please call our customer service on 0800 169 6031 between 10am-9pm as you have won a guaranteed £1000 cash or prize!   |    please or our customer service on 0800 between 6031 169 10am-9pm as you have won a guaranteed £1000 cash call prize!
# this is the 2nd we have tried to contact u. have won the £1450 prize to claim just call 09053750005 b4 310303. prize t&cs/stop atomic_number_62 08718725756. 140ppm   |    this is the 2nd we have contact to tried u. have won the £1450 prize to prize just call 09053750005 b4 310303. claim t&cs/stop atomic_number_62 08718725756. 140ppm
# loans for any purpose even if you have credit! tenants welcome. call noworriesloans.com on 08717111821   |    loans for any purpose even if you have credit! call welcome. tenants noworriesloans.com on 08717111821
# update_now 12mths half price orange line rental: 400mins...call mobileupd8 on 08000839402 or call2optout=j5q   |    update_now call2optout=j5q half price orange line rental: 400mins...call mobileupd8 on 08000839402 or 12mths
# congratulations ur awarded either £500 of cd II vouchers & free entry 2 our £100 weekly draw txt music to tncs www.ldew.com 1 win150ppmx3age16   |    congratulations ur our either £500 of cd II vouchers & free awarded 2 entry £100 weekly draw txt music to tncs www.ldew.com 1 win150ppmx3age16
# urgent we are trying weekend to contact last weekends draw shows u have South_Korean_won a £1000 prize guaranteed call 09064017295 claim k52 valid 12hrs 150p pm   |    urgent we are trying weekend to contact last weekends draw valid u have South_Korean_won a £1000 prize guaranteed call 09064017295 claim k52 pm 12hrs 150p shows
# bonus special D pounds of genuine hmv vouchers to be won. just answer 4 easy questions. four play send hmv to 86688 more info:www.100percent-real.com   |    bonus special D pounds of genuine hmv 4 to be won. answer just vouchers easy questions. four play send hmv to 86688 more info:www.100percent-real.com
# reply to win £100 weekly! where will the 2006 world cup be held? send to 87239 to end service   |    reply held? win £100 weekly! where will the 2006 world cup be to send to 87239 to end service
# recpt you have ordered a ringtone. your order is being processed...   |    recpt you being ordered a ringtone. your order is have processed...
# natalja (25/f) is inviting you to be invite her friend. reply yes-440 or no-440 her: www.sms.ac/u/nat27081980 stop? send stop frnd to   |    natalja (25/f) her inviting you to stop? invite is friend. reply yes-440 or no-440 her: www.sms.ac/u/nat27081980 be send stop frnd to
# free entry into our £250 weekly competition just text the win to 80086 now. XVIII t&c www.txttowin.co.uk   |    free entry into our now. weekly competition just text the win to 80086 £250 XVIII t&c www.txttowin.co.uk
# **free message**thanks for using auction subscription service. 18 . 150p/msgrcvd 2 auction skip an auction txt out. 2 unsubscribe txt stop customercare   |    **free message**thanks for using auction subscription service. 18 . 150p/msgrcvd 2 auction skip an auction txt unsubscribe 2 out. stop txt customercare
# urgent, important information for o2 user. today be fantastical your lucky day! 2 find out log onto http://www.urawinner.com there is fantastic surprise awaiting for you   |    urgent, important information for o2 user. today be fantastical your surprise day! 2 lucky out log onto http://www.urawinner.com there is fantastic find awaiting for you
# t-mobile customer you may now claim your free camera upgrade & A pay go sim card for your loyalty. call on 0845 021 3680.offer ends 28thfeb.t&c's apply   |    t-mobile customer you may now claim your & camera upgrade 0845 A pay go sim card for your loyalty. call on free 021 3680.offer ends 28thfeb.t&c's apply
# want sex in 30 secs? ring 02073162414 now! costs 20p/min gsex pobox 2667 wc1n 3xx   |    want sex in secs? 30 ring 02073162414 now! costs 20p/min gsex pobox 2667 wc1n 3xx
# do you realize in about 40 years, we'll have thousands of around old ladies running around with tattoos?   |    realize you do in about 40 years, we'll have thousands of around old ladies running around with tattoos?
# the sexychat girls are waiting for you to text them. text now a great night chatting. send textual_matter stop to stop this service   |    the sexychat girls are to for you waiting text them. text now a great night chatting. to textual_matter stop send stop this service
# moby pub quiz.win a number_one £100 high street prize u know who the new of cornwall will be? txt her first name prize to 82277.unsub halt £1.50 008704050406 sp   |    moby pub quiz.win a number_one £100 high street txt u know prize the new of cornwall will be? prize her first name who to 82277.unsub halt £1.50 008704050406 sp
# sms. ac sun0819 posts hello:"you cool, wanted to say hi. hi!!!" stop? send stop to 62468   |    sms. ac sun0819 posts stop cool, wanted to say hi. hi!!!" stop? send hello:"you to 62468
# someone u know has asked dating service 2 contact you! cant guess who? call 09058091854 now all will revealed. po box385 m6 6wu   |    someone cant know has asked dating service 2 po you! u guess who? call 09058091854 now all will revealed. contact box385 m6 6wu
# urgent! your mobile 07xxxxxxxxx won angstrom £2,000 bonus caller prize bonus on 02/06/03! this the 2nd attempt to reach you! call 09066362231 asap! box97n7qp, 150ppm   |    urgent! your mobile to won angstrom £2,000 07xxxxxxxxx caller prize bonus on 02/06/03! this the 2nd attempt bonus reach you! call 09066362231 asap! box97n7qp, 150ppm
# valentines solar_day special! win over in quiz and take your partner on the trip of a lifetime! send go to 83600 now. 150p/msg rcvd. custcare:08718720201.   |    valentines rcvd. special! win over in take and quiz your partner on the trip of a lifetime! send go to 83600 now. 150p/msg solar_day custcare:08718720201.
# private! your 2003 chronicle statement for 07973788240 shows 800 un-redeemed statement s. i. m. points. 08715203649 identifier code: 40533 expires   |    private! your m. chronicle statement for 07973788240 40533 800 un-redeemed statement s. i. 2003 points. 08715203649 identifier code: shows expires
# congrats! II mobile 3g videophones r yours. call now! videochat wid ur mates, play java games, dload polyh call music, noline rentl. ip4. 5we. 150pm   |    congrats! videochat mobile 3g videophones r yours. call now! II wid ur mates, games, java play dload polyh call music, noline rentl. ip4. 5we. 150pm
# hot live fantasies now 08707509020 just 20p per min ntt ltd, po box 1327 Po croydon cr9 5wb 0870..k   |    hot live fantasies now 08707509020 just ltd, per min ntt 20p po box 1327 Po croydon cr9 5wb 0870..k
# get your garden ready for summer with free selection of summer bulbs and seeds worth £33:50 only with scotsman this saturday. to stop go2 notxt.co.uk   |    get your garden notxt.co.uk for summer with free selection of summer stop and seeds worth £33:50 only with scotsman this saturday. to bulbs go2 ready
# no 1 polyphonic free tone 4 ur week! just txt pt2 to 87575. 1st tone free ! so get txtin now and tell ur friends. 150p/tone. 16 reply William_Tell hl   |    1st 1 polyphonic free tone 4 ur week! just txt no to 87575. pt2 tone free ! so get txtin now and tell ur friends. 16 150p/tone. reply William_Tell hl
# please call 08712402578 immediately as pressing there is an pressing message waiting for   |    please there 08712402578 immediately as pressing call is an pressing message waiting for
# missed alert. these numbers called but left no message. 07008009200   |    missed alert. these but called numbers left no message. 07008009200
# you are the latest nokia phone, a 40gb ipod mp3 player or a £500 prize! txt word: collect to no: 83355! ibhltd 150p/mtmsgrcvd18   |    a are the latest nokia phone, a 40gb ipod mp3 player or you £500 prize! txt no: collect to word: 83355! ibhltd 150p/mtmsgrcvd18
# your out b4u voucher w/c response 27/03 is marsms. log onto www.b4utele.com for discount credit. to opt out reply stop. care call   |    your marsms. b4u voucher w/c response 27/03 is out log onto call for discount credit. to opt out reply stop. care www.b4utele.com
# twenty-four_hour_period xmas & years eve tickets are now on sale from the club, are during the day from 10am till 8pm, on thurs, fri & sat this week. they're selling fast!   |    twenty-four_hour_period xmas tickets years eve & are now on sale from the club, are during 8pm, day from 10am & the on thurs, fri till sat this week. they're selling fast!
# todays numbers ending with 4882 are to a receive a angstrom £350 award. if your number matches call 09064019014 to match receive your £350 award.   |    todays numbers ending with 4882 are to £350 receive a angstrom £350 award. if your number matches call 09064019014 to match receive your a award.
# urgent! call 09061213237 from landline. £5000 cash or a luxury 4* canary islands holiday collection. t&cs telephone_call sae po box 177. m227xy. 150ppm. 16+   |    urgent! call 09061213237 from landline. £5000 luxury or a cash 4* canary islands holiday collection. t&cs 177. sae po box telephone_call m227xy. 150ppm. 16+
# ar it 80488. your 500 free text messages are valid until 31 december 2005.   |    ar it 80488. your 500 free text messages until valid are 31 december 2005.
# tbs/persolvo. been chasing us since sept for£38 definitely not paying now thanks to information. we will ignore them. kath.   |    tbs/persolvo. been chasing us since them. for£38 definitely not paying now thanks to information. we will ignore sept kath.
# urgent! please call 09066612661 from landline, complimentary 4* lux costa del sol holiday or £1000 cash await collection. ppm 150 sae t&cs james 28, eh74rr   |    urgent! please call 09066612661 from landline, james t&cs lux costa del sol holiday or £1000 cash await collection. ppm 150 sae 4* complimentary 28, eh74rr
# important message. this a final contact attempt. you have out wait important messages waiting out our customer dept. expires 13/4/04. call 08717507382 now!   |    important this message. a final contact attempt. you have out wait important 13/4/04. waiting out our customer dept. expires messages call 08717507382 now!
# thesmszone.com lets you free and masked messages..im sending this message from there..do you see the potential for abuse???   |    thesmszone.com lets you free and masked messages..im sending this message from you there..do see the potential for abuse???
# you 1 new message. please call 08718738034.   |    you please new message. 1 call 08718738034.
# urgent! we are trying to claim contact todays draw shows that you have won a £800 prize guaranteed. call 09050001295 from land claim a21. valid 12hrs only   |    urgent! 12hrs are trying to from contact todays draw shows that you have won a £800 prize guaranteed. call 09050001295 claim land claim a21. valid we only
# we tried to OR you re your reply to our answer offer of 750 mins 150 textand a new video telephone_set call 08002988890 now or reply for free delivery   |    we tried to OR offer video your reply to our answer you of 750 mins 150 textand a new re telephone_set call 08002988890 now or reply for free delivery

# %%
eda_df = pd.DataFrame({"Message": augmented_texts, "Category": "spam"})
df_train_eda = pd.concat([df_train, eda_df])

# %%
df_train_eda["Category"].value_counts()
# Out:
# ham     3619
# spam    1120
# Name: Category, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

df_train_eda["Message"] = df_train_eda["Message"].str.lower()

df_train_eda["Message"] = df_train_eda["Message"].fillna(" ")

# perform TFIDF
X_train_eda_tfidf = tfidf.transform(df_train_eda["Message"])
lr = LogisticRegression()
lr.fit(X_train_eda_tfidf, df_train_eda["Category"])
print(classification_report(y_test, lr.predict(X_test_tfidf)))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      0.99      0.99      1206
#         spam       0.96      0.90      0.93       187
#
#     accuracy                           0.98      1393
#    macro avg       0.97      0.95      0.96      1393
# weighted avg       0.98      0.98      0.98      1393
